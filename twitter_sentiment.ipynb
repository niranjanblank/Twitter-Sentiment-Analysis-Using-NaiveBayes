# %%
from nltk.corpus import stopwords, twitter_samples
from nltk.stem import PorterStemmer
import re
import numpy as np
import pandas as pd
import string
import nltk
from nltk.tokenize import TweetTokenizer

# %%
#getting the positive and negative tweets
positive_tweets = twitter_samples.strings('positive_tweets.json')
negative_tweets = twitter_samples.strings('negative_tweets.json')

# %%
#split data for training and testing
train_positive = positive_tweets[:4000]
test_positive = positive_tweets[4000:]

train_negative = negative_tweets[:4000]
test_negative = negative_tweets[4000:]

train_x = train_positive + train_negative
test_x = test_positive + test_negative

train_y = np.append(np.ones(len(train_positive)), np.zeros(len(train_negative)))
test_y = np.append(np.ones(len(test_positive)), np.zeros(len(test_negative)))

# %%
train_positive[0:10]
# Out:
# ['#FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)',
#  '@Lamb2ja Hey James! How odd :/ Please call our Contact Centre on 02392441234 and we will be able to assist you :) Many thanks!',
#  '@DespiteOfficial we had a listen last night :) As You Bleed is an amazing track. When are you in Scotland?!',
#  '@97sides CONGRATS :)',
#  'yeaaaah yippppy!!!  my accnt verified rqst has succeed got a blue tick mark on my fb profile :) in 15 days',
#  '@BhaktisBanter @PallaviRuhail This one is irresistible :)\n#FlipkartFashionFriday http://t.co/EbZ0L2VENM',
#  "We don't like to keep our lovely customers waiting for long! We hope you enjoy! Happy Friday! - LWWF :) https://t.co/smyYriipxI",
#  '@Impatientraider On second thought, there’s just not enough time for a DD :) But new shorts entering system. Sheep must be buying.',
#  'Jgh , but we have to go to Bayan :D bye',
#  'As an act of mischievousness, am calling the ETL layer of our in-house warehousing app Katamari.\n\nWell… as the name implies :p.']

# %%
train_negative[0:10]
# Out:
# ['hopeless for tmr :(',
#  "Everything in the kids section of IKEA is so cute. Shame I'm nearly 19 in 2 months :(",
#  '@Hegelbon That heart sliding into the waste basket. :(',
#  '“@ketchBurning: I hate Japanese call him "bani" :( :(”\n\nMe too',
#  'Dang starting next week I have "work" :(',
#  "oh god, my babies' faces :( https://t.co/9fcwGvaki0",
#  '@RileyMcDonough make me smile :((',
#  '@f0ggstar @stuartthull work neighbour on motors. Asked why and he said hates the updates on search :( http://t.co/XvmTUikWln',
#  'why?:("@tahuodyy: sialan:( https://t.co/Hv1i0xcrL2"',
#  'Athabasca glacier was there in #1948 :-( #athabasca #glacier #jasper #jaspernationalpark #alberta #explorealberta #… http://t.co/dZZdqmf7Cz']

# %%
def clean_tweet(tweet):
    stemmer = PorterStemmer()
    stopwords_english = stopwords.words('english')
    
    tweet = re.sub(r'\$\w*','',tweet)
    # remove retweet text "RT"
    tweet = re.sub(r'RT[\s]+','',tweet)
    # remove hyperlinks
    tweet = re.sub(r'https?:\/\/.*[\r\n]*','',tweet)
    #remove # sign
    tweet = re.sub(r'#','',tweet)
    #tokenizing the tweets
    tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True,
                               reduce_len=True)
    tweet_tokens = tokenizer.tokenize(tweet)
    
    cleaned_tweet=[]
    for word in tweet_tokens:
        if(word not in stopwords_english and word not in string.punctuation):
            stem_word = stemmer.stem(word)
            cleaned_tweet.append(stem_word)
    return cleaned_tweet

# %%
clean_tweet(train_negative[0])
# Out:
# ['hopeless', 'tmr', ':(']

# %%
def count_tweets(result, tweets, sentiment):
    #result= preexisting dictionary
    #tweets = group of tweets
    #sentiment = group of tags of the tweets supplies
    for tag,tweet in zip(sentiment,tweets):
        cleaned_tweet = clean_tweet(tweet)
        for word in cleaned_tweet:
            pair = (word,tag)
            
            result[pair] = result.get(pair,0) + 1
            
#             if pair in result:
#                 result[pair] += 1
#             else:
#                 result[pair] += 1
    return result

# %%
result = {}
tweets = ['i am happy', 'i am tricked', 'i am sad', 'i am tired', 'i am tired']
ys = [1, 0, 0, 0, 0]
count_tweets(result, tweets, ys)
# Out:
# {('happi', 1): 1, ('trick', 0): 1, ('sad', 0): 1, ('tire', 0): 2}

# %%
#getting the frequencies of all the words
freqs = count_tweets({},train_x,train_y)

# %%
freqs
# Out:
# {('followfriday', 1.0): 23,
#  ('top', 1.0): 30,
#  ('engag', 1.0): 7,
#  ('member', 1.0): 14,
#  ('commun', 1.0): 27,
#  ('week', 1.0): 72,
#  (':)', 1.0): 2847,
#  ('hey', 1.0): 60,
#  ('jame', 1.0): 7,
#  ('odd', 1.0): 2,
#  (':/', 1.0): 5,
#  ('pleas', 1.0): 80,
#  ('call', 1.0): 27,
#  ('contact', 1.0): 4,
#  ('centr', 1.0): 1,
#  ('02392441234', 1.0): 1,
#  ('abl', 1.0): 6,
#  ('assist', 1.0): 1,
#  ('mani', 1.0): 28,
#  ('thank', 1.0): 504,
#  ('listen', 1.0): 14,
#  ('last', 1.0): 39,
#  ('night', 1.0): 55,
#  ('bleed', 1.0): 2,
#  ('amaz', 1.0): 41,
#  ('track', 1.0): 5,
#  ('scotland', 1.0): 2,
#  ('congrat', 1.0): 15,
#  ('yeaaah', 1.0): 1,
#  ('yipppi', 1.0): 1,
#  ('accnt', 1.0): 2,
#  ('verifi', 1.0): 2,
#  ('rqst', 1.0): 1,
#  ('succeed', 1.0): 1,
#  ('got', 1.0): 57,
#  ('blue', 1.0): 8,
#  ('tick', 1.0): 1,
#  ('mark', 1.0): 1,
#  ('fb', 1.0): 4,
#  ('profil', 1.0): 2,
#  ('15', 1.0): 4,
#  ('day', 1.0): 187,
#  ('one', 1.0): 90,
#  ('irresist', 1.0): 2,
#  ('flipkartfashionfriday', 1.0): 16,
#  ('like', 1.0): 187,
#  ('keep', 1.0): 55,
#  ('love', 1.0): 335,
#  ('custom', 1.0): 4,
#  ('wait', 1.0): 55,
#  ('long', 1.0): 27,
#  ('hope', 1.0): 113,
#  ('enjoy', 1.0): 57,
#  ('happi', 1.0): 161,
#  ('friday', 1.0): 91,
#  ('lwwf', 1.0): 1,
#  ('second', 1.0): 8,
#  ('thought', 1.0): 21,
#  ('’', 1.0): 17,
#  ('enough', 1.0): 16,
#  ('time', 1.0): 100,
#  ('dd', 1.0): 1,
#  ('new', 1.0): 111,
#  ('short', 1.0): 6,
#  ('enter', 1.0): 9,
#  ('system', 1.0): 2,
#  ('sheep', 1.0): 1,
#  ('must', 1.0): 14,
#  ('buy', 1.0): 9,
#  ('jgh', 1.0): 4,
#  ('go', 1.0): 120,
#  ('bayan', 1.0): 1,
#  (':D', 1.0): 498,
#  ('bye', 1.0): 5,
#  ('act', 1.0): 6,
#  ('mischiev', 1.0): 1,
#  ('etl', 1.0): 1,
#  ('layer', 1.0): 1,
#  ('in-hous', 1.0): 1,
#  ('wareh', 1.0): 1,
#  ('app', 1.0): 12,
#  ('katamari', 1.0): 1,
#  ('well', 1.0): 66,
#  ('…', 1.0): 31,
#  ('name', 1.0): 12,
#  ('impli', 1.0): 1,
#  (':p', 1.0): 103,
#  ('influenc', 1.0): 16,
#  ('big', 1.0): 27,
#  ('...', 1.0): 227,
#  ('juici', 1.0): 3,
#  ('selfi', 1.0): 11,
#  ('follow', 1.0): 319,
#  ('perfect', 1.0): 17,
#  ('alreadi', 1.0): 19,
#  ('know', 1.0): 120,
#  ("what'", 1.0): 14,
#  ('great', 1.0): 134,
#  ('opportun', 1.0): 17,
#  ('junior', 1.0): 2,
#  ('triathlet', 1.0): 1,
#  ('age', 1.0): 2,
#  ('12', 1.0): 5,
#  ('13', 1.0): 5,
#  ('gatorad', 1.0): 1,
#  ('seri', 1.0): 4,
#  ('get', 1.0): 164,
#  ('entri', 1.0): 3,
#  ('lay', 1.0): 3,
#  ('greet', 1.0): 4,
#  ('card', 1.0): 6,
#  ('rang', 1.0): 2,
#  ('print', 1.0): 3,
#  ('today', 1.0): 86,
#  ('job', 1.0): 34,
#  (':-)', 1.0): 543,
#  ("friend'", 1.0): 3,
#  ('lunch', 1.0): 3,
#  ('yummm', 1.0): 1,
#  ('nostalgia', 1.0): 1,
#  ('tb', 1.0): 1,
#  ('ku', 1.0): 1,
#  ('id', 1.0): 8,
#  ('conflict', 1.0): 1,
#  ('help', 1.0): 37,
#  ("here'", 1.0): 20,
#  ('screenshot', 1.0): 2,
#  ('work', 1.0): 88,
#  ('hi', 1.0): 154,
#  ('liv', 1.0): 2,
#  ('hello', 1.0): 49,
#  ('need', 1.0): 62,
#  ('someth', 1.0): 25,
#  ('u', 1.0): 136,
#  ('fm', 1.0): 2,
#  ('twitter', 1.0): 25,
#  ('—', 1.0): 22,
#  ('sure', 1.0): 37,
#  ('thing', 1.0): 48,
#  ('dm', 1.0): 34,
#  ('x', 1.0): 50,
#  ("i'v", 1.0): 25,
#  ('heard', 1.0): 9,
#  ('four', 1.0): 5,
#  ('season', 1.0): 5,
#  ('pretti', 1.0): 17,
#  ('dope', 1.0): 2,
#  ('penthous', 1.0): 1,
#  ('obv', 1.0): 1,
#  ('gobigorgohom', 1.0): 1,
#  ('fun', 1.0): 45,
#  ("y'all", 1.0): 3,
#  ('yeah', 1.0): 30,
#  ('suppos', 1.0): 6,
#  ('lol', 1.0): 48,
#  ('chat', 1.0): 9,
#  ('bit', 1.0): 16,
#  ('youth', 1.0): 14,
#  ('💅', 1.0): 1,
#  ('🏽', 1.0): 1,
#  ('💋', 1.0): 2,
#  ('seen', 1.0): 6,
#  ('year', 1.0): 33,
#  ('rest', 1.0): 9,
#  ('goe', 1.0): 4,
#  ('quickli', 1.0): 3,
#  ('bed', 1.0): 8,
#  ('music', 1.0): 15,
#  ('fix', 1.0): 6,
#  ('dream', 1.0): 17,
#  ('spiritu', 1.0): 1,
#  ('ritual', 1.0): 1,
#  ('festiv', 1.0): 7,
#  ('népal', 1.0): 1,
#  ('begin', 1.0): 4,
#  ('line-up', 1.0): 4,
#  ('left', 1.0): 10,
#  ('see', 1.0): 156,
#  ('sarah', 1.0): 4,
#  ('send', 1.0): 17,
#  ('us', 1.0): 91,
#  ('email', 1.0): 22,
#  ('bitsy@bitdefender.com', 1.0): 1,
#  ("we'll", 1.0): 12,
#  ('asap', 1.0): 5,
#  ('kik', 1.0): 16,
#  ('hatessuc', 1.0): 1,
#  ('32429', 1.0): 1,
#  ('kikm', 1.0): 1,
#  ('lgbt', 1.0): 2,
#  ('tinder', 1.0): 1,
#  ('nsfw', 1.0): 1,
#  ('akua', 1.0): 1,
#  ('cumshot', 1.0): 1,
#  ('come', 1.0): 63,
#  ('hous', 1.0): 5,
#  ('nsn_supplement', 1.0): 1,
#  ('effect', 1.0): 2,
#  ('press', 1.0): 1,
#  ('releas', 1.0): 11,
#  ('distribut', 1.0): 1,
#  ('result', 1.0): 2,
#  ('link', 1.0): 13,
#  ('remov', 1.0): 3,
#  ('pressreleas', 1.0): 1,
#  ('newsdistribut', 1.0): 1,
#  ('bam', 1.0): 44,
#  ('bestfriend', 1.0): 50,
#  ('lot', 1.0): 80,
#  ('warsaw', 1.0): 44,
#  ('<3', 1.0): 118,
#  ('x46', 1.0): 1,
#  ('everyon', 1.0): 45,
#  ('watch', 1.0): 32,
#  ('documentari', 1.0): 1,
#  ('earthl', 1.0): 1,
#  ('youtub', 1.0): 8,
#  ('support', 1.0): 25,
#  ('buuut', 1.0): 1,
#  ('oh', 1.0): 44,
#  ('look', 1.0): 109,
#  ('forward', 1.0): 20,
#  ('visit', 1.0): 25,
#  ('next', 1.0): 37,
#  ('letsgetmessi', 1.0): 1,
#  ('jo', 1.0): 1,
#  ('make', 1.0): 69,
#  ('feel', 1.0): 33,
#  ('better', 1.0): 40,
#  ('never', 1.0): 31,
#  ('anyon', 1.0): 7,
#  ('kpop', 1.0): 1,
#  ('flesh', 1.0): 1,
#  ('good', 1.0): 191,
#  ('girl', 1.0): 34,
#  ('best', 1.0): 49,
#  ('wish', 1.0): 29,
#  ('reason', 1.0): 10,
#  ('epic', 1.0): 1,
#  ('soundtrack', 1.0): 1,
#  ('shout', 1.0): 11,
#  ('ad', 1.0): 10,
#  ('video', 1.0): 29,
#  ('playlist', 1.0): 5,
#  ('would', 1.0): 70,
#  ('dear', 1.0): 15,
#  ('jordan', 1.0): 1,
#  ('okay', 1.0): 31,
#  ('fake', 1.0): 1,
#  ('gameplay', 1.0): 1,
#  (';)', 1.0): 22,
#  ('haha', 1.0): 44,
#  ('im', 1.0): 38,
#  ('kid', 1.0): 13,
#  ('stuff', 1.0): 11,
#  ('exactli', 1.0): 5,
#  ('product', 1.0): 11,
#  ('line', 1.0): 6,
#  ('etsi', 1.0): 1,
#  ('shop', 1.0): 12,
#  ('check', 1.0): 38,
#  ('vacat', 1.0): 5,
#  ('recharg', 1.0): 1,
#  ('normal', 1.0): 5,
#  ('charger', 1.0): 2,
#  ('asleep', 1.0): 7,
#  ('talk', 1.0): 37,
#  ('sooo', 1.0): 6,
#  ('someon', 1.0): 29,
#  ('text', 1.0): 12,
#  ('ye', 1.0): 60,
#  ('bet', 1.0): 6,
#  ("he'll", 1.0): 2,
#  ('fit', 1.0): 2,
#  ('hear', 1.0): 24,
#  ('speech', 1.0): 1,
#  ('piti', 1.0): 2,
#  ('green', 1.0): 2,
#  ('garden', 1.0): 5,
#  ('midnight', 1.0): 1,
#  ('sun', 1.0): 6,
#  ('beauti', 1.0): 45,
#  ('canal', 1.0): 1,
#  ('dasvidaniya', 1.0): 1,
#  ('till', 1.0): 16,
#  ('scout', 1.0): 1,
#  ('sg', 1.0): 1,
#  ('futur', 1.0): 9,
#  ('wlan', 1.0): 1,
#  ('pro', 1.0): 4,
#  ('confer', 1.0): 1,
#  ('asia', 1.0): 1,
#  ('chang', 1.0): 20,
#  ('lollipop', 1.0): 1,
#  ('🍭', 1.0): 1,
#  ('nez', 1.0): 1,
#  ('agnezmo', 1.0): 1,
#  ('oley', 1.0): 1,
#  ('mama', 1.0): 1,
#  ('stand', 1.0): 6,
#  ('stronger', 1.0): 1,
#  ('god', 1.0): 14,
#  ('misti', 1.0): 1,
#  ('babi', 1.0): 17,
#  ('cute', 1.0): 21,
#  ('woohoo', 1.0): 3,
#  ("can't", 1.0): 31,
#  ('sign', 1.0): 9,
#  ('yet', 1.0): 12,
#  ('still', 1.0): 37,
#  ('think', 1.0): 48,
#  ('mka', 1.0): 5,
#  ('liam', 1.0): 5,
#  ('access', 1.0): 3,
#  ('welcom', 1.0): 54,
#  ('stat', 1.0): 51,
#  ('arriv', 1.0): 57,
#  ('1', 1.0): 60,
#  ('unfollow', 1.0): 53,
#  ('via', 1.0): 60,
#  ('surpris', 1.0): 10,
#  ('figur', 1.0): 5,
#  ('happybirthdayemilybett', 1.0): 1,
#  ('sweet', 1.0): 16,
#  ('talent', 1.0): 4,
#  ('2', 1.0): 40,
#  ('plan', 1.0): 21,
#  ('drain', 1.0): 1,
#  ('gotta', 1.0): 4,
#  ('timezon', 1.0): 1,
#  ('parent', 1.0): 4,
#  ('proud', 1.0): 11,
#  ('least', 1.0): 14,
#  ('mayb', 1.0): 17,
#  ('sometim', 1.0): 11,
#  ('grade', 1.0): 4,
#  ('al', 1.0): 3,
#  ('grand', 1.0): 4,
#  ('manila_bro', 1.0): 1,
#  ('chosen', 1.0): 1,
#  ('let', 1.0): 57,
#  ('around', 1.0): 14,
#  ('..', 1.0): 100,
#  ('side', 1.0): 13,
#  ('world', 1.0): 23,
#  ('eh', 1.0): 2,
#  ('take', 1.0): 30,
#  ('care', 1.0): 12,
#  ('final', 1.0): 24,
#  ('fuck', 1.0): 20,
#  ('weekend', 1.0): 61,
#  ('real', 1.0): 18,
#  ('x45', 1.0): 1,
#  ('join', 1.0): 21,
#  ('hushedcallwithfraydo', 1.0): 1,
#  ('gift', 1.0): 7,
#  ('yeahhh', 1.0): 1,
#  ('hushedpinwithsammi', 1.0): 2,
#  ('event', 1.0): 7,
#  ('might', 1.0): 21,
#  ('luv', 1.0): 4,
#  ('realli', 1.0): 66,
#  ('appreci', 1.0): 28,
#  ('share', 1.0): 41,
#  ('wow', 1.0): 14,
#  ('tom', 1.0): 5,
#  ('gym', 1.0): 3,
#  ('monday', 1.0): 7,
#  ('invit', 1.0): 15,
#  ('scope', 1.0): 5,
#  ('friend', 1.0): 40,
#  ('nude', 1.0): 1,
#  ('sleep', 1.0): 35,
#  ('birthday', 1.0): 53,
#  ('want', 1.0): 69,
#  ('t-shirt', 1.0): 2,
#  ('cool', 1.0): 29,
#  ('haw', 1.0): 1,
#  ('phela', 1.0): 1,
#  ('mom', 1.0): 7,
#  ('obvious', 1.0): 1,
#  ('princ', 1.0): 1,
#  ('charm', 1.0): 1,
#  ('stage', 1.0): 2,
#  ('luck', 1.0): 26,
#  ('tyler', 1.0): 1,
#  ('hipster', 1.0): 1,
#  ('glass', 1.0): 3,
#  ('marti', 1.0): 2,
#  ('glad', 1.0): 41,
#  ('done', 1.0): 40,
#  ('afternoon', 1.0): 7,
#  ('read', 1.0): 27,
#  ('kahfi', 1.0): 1,
#  ('finish', 1.0): 15,
#  ('ohmyg', 1.0): 1,
#  ('yaya', 1.0): 3,
#  ('dub', 1.0): 1,
#  ('stalk', 1.0): 2,
#  ('ig', 1.0): 3,
#  ('gondooo', 1.0): 1,
#  ('moo', 1.0): 2,
#  ('tologooo', 1.0): 1,
#  ('becom', 1.0): 8,
#  ('detail', 1.0): 8,
#  ('zzz', 1.0): 1,
#  ('xx', 1.0): 33,
#  ('physiotherapi', 1.0): 1,
#  ('hashtag', 1.0): 3,
#  ('💪', 1.0): 1,
#  ('monica', 1.0): 1,
#  ('miss', 1.0): 17,
#  ('sound', 1.0): 20,
#  ('morn', 1.0): 68,
#  ("that'", 1.0): 49,
#  ('x43', 1.0): 1,
#  ('definit', 1.0): 20,
#  ('tri', 1.0): 34,
#  ('tonight', 1.0): 15,
#  ('took', 1.0): 7,
#  ('advic', 1.0): 6,
#  ('treviso', 1.0): 1,
#  ('concert', 1.0): 23,
#  ('citi', 1.0): 26,
#  ('countri', 1.0): 22,
#  ("i'll", 1.0): 73,
#  ('start', 1.0): 56,
#  ('fine', 1.0): 7,
#  ('gorgeou', 1.0): 9,
#  ('xo', 1.0): 2,
#  ('oven', 1.0): 2,
#  ('roast', 1.0): 1,
#  ('garlic', 1.0): 1,
#  ('oliv', 1.0): 1,
#  ('oil', 1.0): 4,
#  ('dri', 1.0): 4,
#  ('tomato', 1.0): 1,
#  ('basil', 1.0): 1,
#  ('centuri', 1.0): 1,
#  ('tuna', 1.0): 1,
#  ('right', 1.0): 38,
#  ('back', 1.0): 74,
#  ('atchya', 1.0): 1,
#  ('even', 1.0): 26,
#  ('almost', 1.0): 8,
#  ('chanc', 1.0): 3,
#  ('cheer', 1.0): 17,
#  ('po', 1.0): 3,
#  ('ice', 1.0): 6,
#  ('cream', 1.0): 6,
#  ('agre', 1.0): 13,
#  ('100', 1.0): 6,
#  ('heheheh', 1.0): 2,
#  ('that', 1.0): 10,
#  ('point', 1.0): 11,
#  ('stay', 1.0): 20,
#  ('home', 1.0): 20,
#  ('soon', 1.0): 38,
#  ('promis', 1.0): 4,
#  ('web', 1.0): 4,
#  ('whatsapp', 1.0): 3,
#  ('volta', 1.0): 1,
#  ('funcionar', 1.0): 1,
#  ('com', 1.0): 2,
#  ('iphon', 1.0): 7,
#  ('jailbroken', 1.0): 1,
#  ('later', 1.0): 11,
#  ('34', 1.0): 3,
#  ('min', 1.0): 7,
#  ('leia', 1.0): 1,
#  ('appear', 1.0): 3,
#  ('hologram', 1.0): 1,
#  ('r2d2', 1.0): 1,
#  ('w', 1.0): 16,
#  ('messag', 1.0): 9,
#  ('obi', 1.0): 1,
#  ('wan', 1.0): 1,
#  ('sit', 1.0): 7,
#  ('luke', 1.0): 4,
#  ('inter', 1.0): 1,
#  ('3', 1.0): 26,
#  ('ucl', 1.0): 1,
#  ('arsen', 1.0): 2,
#  ('small', 1.0): 1,
#  ('team', 1.0): 24,
#  ('pass', 1.0): 10,
#  ('🚂', 1.0): 1,
#  ('dewsburi', 1.0): 2,
#  ('railway', 1.0): 1,
#  ('station', 1.0): 4,
#  ('dew', 1.0): 1,
#  ('west', 1.0): 1,
#  ('yorkshir', 1.0): 2,
#  ('430', 1.0): 1,
#  ('smh', 1.0): 2,
#  ('9:25', 1.0): 1,
#  ('live', 1.0): 21,
#  ('strang', 1.0): 4,
#  ('imagin', 1.0): 5,
#  ('megan', 1.0): 1,
#  ('masaantoday', 1.0): 4,
#  ('a4', 1.0): 3,
#  ('shweta', 1.0): 1,
#  ('tripathi', 1.0): 1,
#  ('5', 1.0): 15,
#  ('20', 1.0): 5,
#  ('kurta', 1.0): 3,
#  ('half', 1.0): 6,
#  ('number', 1.0): 11,
#  ('wsalelov', 1.0): 14,
#  ('ah', 1.0): 12,
#  ('larri', 1.0): 3,
#  ('anyway', 1.0): 14,
#  ('kinda', 1.0): 12,
#  ('goood', 1.0): 1,
#  ('life', 1.0): 36,
#  ('enn', 1.0): 1,
#  ('could', 1.0): 25,
#  ('warmup', 1.0): 1,
#  ('15th', 1.0): 2,
#  ('bath', 1.0): 6,
#  ('dum', 1.0): 2,
#  ('andar', 1.0): 1,
#  ('ram', 1.0): 1,
#  ('sampath', 1.0): 1,
#  ('sona', 1.0): 1,
#  ('mohapatra', 1.0): 1,
#  ('samantha', 1.0): 1,
#  ('edward', 1.0): 1,
#  ('mein', 1.0): 1,
#  ('tulan', 1.0): 1,
#  ('razi', 1.0): 2,
#  ('wah', 1.0): 2,
#  ('josh', 1.0): 1,
#  ('alway', 1.0): 48,
#  ('smile', 1.0): 47,
#  ('pictur', 1.0): 7,
#  ('16.20', 1.0): 1,
#  ('giveitup', 1.0): 1,
#  ('given', 1.0): 3,
#  ('ga', 1.0): 3,
#  ('subsidi', 1.0): 1,
#  ('initi', 1.0): 2,
#  ('propos', 1.0): 3,
#  ('delight', 1.0): 4,
#  ('yesterday', 1.0): 4,
#  ('x42', 1.0): 1,
#  ('lmaoo', 1.0): 2,
#  ('song', 1.0): 16,
#  ('ever', 1.0): 19,
#  ('shall', 1.0): 5,
#  ('littl', 1.0): 29,
#  ('throwback', 1.0): 3,
#  ('outli', 1.0): 1,
#  ('island', 1.0): 2,
#  ('cheung', 1.0): 1,
#  ('chau', 1.0): 1,
#  ('mui', 1.0): 1,
#  ('wo', 1.0): 1,
#  ('total', 1.0): 5,
#  ('differ', 1.0): 10,
#  ('kfckitchentour', 1.0): 2,
#  ('kitchen', 1.0): 3,
#  ('clean', 1.0): 1,
#  ("i'm", 1.0): 140,
#  ('cusp', 1.0): 1,
#  ('test', 1.0): 7,
#  ('water', 1.0): 7,
#  ('reward', 1.0): 1,
#  ('arummzz', 1.0): 2,
#  ("let'", 1.0): 18,
#  ('drive', 1.0): 9,
#  ('travel', 1.0): 19,
#  ('yogyakarta', 1.0): 3,
#  ('jeep', 1.0): 3,
#  ('indonesia', 1.0): 3,
#  ('instamood', 1.0): 3,
#  ('wanna', 1.0): 23,
#  ('skype', 1.0): 3,
#  ('may', 1.0): 16,
#  ('nice', 1.0): 70,
#  ('friendli', 1.0): 1,
#  ('pretend', 1.0): 2,
#  ('film', 1.0): 8,
#  ('congratul', 1.0): 9,
#  ('winner', 1.0): 3,
#  ('cheesydelight', 1.0): 1,
#  ('contest', 1.0): 5,
#  ('address', 1.0): 8,
#  ('guy', 1.0): 48,
#  ('market', 1.0): 5,
#  ('24/7', 1.0): 1,
#  ('14', 1.0): 1,
#  ('hour', 1.0): 24,
#  ('leav', 1.0): 11,
#  ('without', 1.0): 9,
#  ('delay', 1.0): 1,
#  ('actual', 1.0): 13,
#  ('easi', 1.0): 7,
#  ('guess', 1.0): 8,
#  ('train', 1.0): 7,
#  ('wd', 1.0): 1,
#  ('shift', 1.0): 4,
#  ('engin', 1.0): 1,
#  ('etc', 1.0): 2,
#  ('sunburn', 1.0): 1,
#  ('peel', 1.0): 2,
#  ('blog', 1.0): 27,
#  ('huge', 1.0): 9,
#  ('warm', 1.0): 4,
#  ('☆', 1.0): 3,
#  ('complet', 1.0): 10,
#  ('triangl', 1.0): 2,
#  ('northern', 1.0): 1,
#  ('ireland', 1.0): 2,
#  ('sight', 1.0): 1,
#  ('smthng', 1.0): 2,
#  ('fr', 1.0): 3,
#  ('hug', 1.0): 11,
#  ('xoxo', 1.0): 3,
#  ('uu', 1.0): 1,
#  ('jaann', 1.0): 1,
#  ('topnewfollow', 1.0): 2,
#  ('connect', 1.0): 13,
#  ('wonder', 1.0): 26,
#  ('made', 1.0): 38,
#  ('fluffi', 1.0): 1,
#  ('insid', 1.0): 7,
#  ('pirouett', 1.0): 1,
#  ('moos', 1.0): 1,
#  ('trip', 1.0): 12,
#  ('philli', 1.0): 1,
#  ('decemb', 1.0): 2,
#  ("i'd", 1.0): 13,
#  ('dude', 1.0): 6,
#  ('x41', 1.0): 1,
#  ('question', 1.0): 15,
#  ('flaw', 1.0): 1,
#  ('pain', 1.0): 8,
#  ('negat', 1.0): 1,
#  ('strength', 1.0): 2,
#  ('went', 1.0): 10,
#  ('solo', 1.0): 4,
#  ('move', 1.0): 9,
#  ('fav', 1.0): 11,
#  ('nirvana', 1.0): 1,
#  ('smell', 1.0): 2,
#  ('teen', 1.0): 3,
#  ('spirit', 1.0): 1,
#  ('rip', 1.0): 3,
#  ('ami', 1.0): 4,
#  ('winehous', 1.0): 1,
#  ('coupl', 1.0): 5,
#  ('tomhiddleston', 1.0): 1,
#  ('elizabetholsen', 1.0): 1,
#  ('yaytheylookgreat', 1.0): 1,
#  ('goodnight', 1.0): 18,
#  ('vid', 1.0): 8,
#  ('wake', 1.0): 10,
#  ('gonna', 1.0): 16,
#  ('shoot', 1.0): 5,
#  ('itti', 1.0): 2,
#  ('bitti', 1.0): 2,
#  ('teeni', 1.0): 2,
#  ('bikini', 1.0): 3,
#  ('much', 1.0): 73,
#  ('4th', 1.0): 4,
#  ('togeth', 1.0): 6,
#  ('end', 1.0): 13,
#  ('xfile', 1.0): 1,
#  ('content', 1.0): 3,
#  ('rain', 1.0): 18,
#  ('fabul', 1.0): 4,
#  ('fantast', 1.0): 8,
#  ('♡', 1.0): 12,
#  ('jb', 1.0): 1,
#  ('forev', 1.0): 5,
#  ('belieb', 1.0): 3,
#  ('nighti', 1.0): 1,
#  ('bug', 1.0): 2,
#  ('bite', 1.0): 1,
#  ('bracelet', 1.0): 2,
#  ('idea', 1.0): 23,
#  ('foundri', 1.0): 1,
#  ('game', 1.0): 23,
#  ('sens', 1.0): 6,
#  ('pic', 1.0): 21,
#  ('ef', 1.0): 1,
#  ('phone', 1.0): 16,
#  ('woot', 1.0): 2,
#  ('derek', 1.0): 1,
#  ('use', 1.0): 32,
#  ('parkshar', 1.0): 1,
#  ('gloucestershir', 1.0): 1,
#  ('aaaahhh', 1.0): 1,
#  ('man', 1.0): 16,
#  ('traffic', 1.0): 2,
#  ('stress', 1.0): 4,
#  ('reliev', 1.0): 1,
#  ("how'r", 1.0): 1,
#  ('arbeloa', 1.0): 1,
#  ('turn', 1.0): 13,
#  ('17', 1.0): 2,
#  ('omg', 1.0): 13,
#  ('say', 1.0): 43,
#  ('europ', 1.0): 1,
#  ('rise', 1.0): 2,
#  ('find', 1.0): 20,
#  ('hard', 1.0): 9,
#  ('believ', 1.0): 7,
#  ('uncount', 1.0): 1,
#  ('coz', 1.0): 2,
#  ('unlimit', 1.0): 1,
#  ('cours', 1.0): 11,
#  ('teamposit', 1.0): 1,
#  ('aldub', 1.0): 2,
#  ('☕', 1.0): 3,
#  ('rita', 1.0): 2,
#  ('info', 1.0): 10,
#  ("we'd", 1.0): 4,
#  ('way', 1.0): 34,
#  ('boy', 1.0): 13,
#  ('x40', 1.0): 1,
#  ('true', 1.0): 19,
#  ('sethi', 1.0): 2,
#  ('high', 1.0): 6,
#  ('exe', 1.0): 1,
#  ('skeem', 1.0): 1,
#  ('saam', 1.0): 1,
#  ('peopl', 1.0): 42,
#  ('polit', 1.0): 2,
#  ('izzat', 1.0): 1,
#  ('wese', 1.0): 1,
#  ('trust', 1.0): 7,
#  ('khawateen', 1.0): 1,
#  ('k', 1.0): 8,
#  ('sath', 1.0): 2,
#  ('mana', 1.0): 1,
#  ('kar', 1.0): 1,
#  ('deya', 1.0): 1,
#  ('sort', 1.0): 7,
#  ('smart', 1.0): 5,
#  ('hair', 1.0): 7,
#  ('tbh', 1.0): 5,
#  ('jacob', 1.0): 2,
#  ('g', 1.0): 7,
#  ('upgrad', 1.0): 2,
#  ('tee', 1.0): 2,
#  ('famili', 1.0): 14,
#  ('person', 1.0): 14,
#  ('two', 1.0): 15,
#  ('convers', 1.0): 6,
#  ('onlin', 1.0): 4,
#  ('mclaren', 1.0): 1,
#  ('fridayfeel', 1.0): 5,
#  ('tgif', 1.0): 8,
#  ('squar', 1.0): 1,
#  ('enix', 1.0): 1,
#  ('bissmillah', 1.0): 1,
#  ('ya', 1.0): 19,
#  ('allah', 1.0): 3,
#  ("we'r", 1.0): 25,
#  ('socent', 1.0): 1,
#  ('startup', 1.0): 2,
#  ('drop', 1.0): 9,
#  ('your', 1.0): 3,
#  ('arnd', 1.0): 1,
#  ('town', 1.0): 3,
#  ('basic', 1.0): 4,
#  ('piss', 1.0): 2,
#  ('cup', 1.0): 4,
#  ('also', 1.0): 28,
#  ('terribl', 1.0): 2,
#  ('complic', 1.0): 1,
#  ('discuss', 1.0): 2,
#  ('snapchat', 1.0): 31,
#  ('lynettelow', 1.0): 1,
#  ('kikmenow', 1.0): 2,
#  ('snapm', 1.0): 1,
#  ('hot', 1.0): 20,
#  ('amazon', 1.0): 1,
#  ('kikmeguy', 1.0): 2,
#  ('defin', 1.0): 2,
#  ('grow', 1.0): 6,
#  ('sport', 1.0): 4,
#  ('rt', 1.0): 9,
#  ('rakyat', 1.0): 1,
#  ('write', 1.0): 11,
#  ('sinc', 1.0): 11,
#  ('mention', 1.0): 18,
#  ('fli', 1.0): 5,
#  ('fish', 1.0): 3,
#  ('promot', 1.0): 3,
#  ('post', 1.0): 16,
#  ('cyber', 1.0): 1,
#  ('ourdaughtersourprid', 1.0): 3,
#  ('mypapamyprid', 1.0): 2,
#  ('papa', 1.0): 1,
#  ('coach', 1.0): 2,
#  ('posit', 1.0): 3,
#  ('kha', 1.0): 1,
#  ('atleast', 1.0): 2,
#  ('x39', 1.0): 1,
#  ('mango', 1.0): 1,
#  ("lassi'", 1.0): 1,
#  ("monty'", 1.0): 1,
#  ('marvel', 1.0): 2,
#  ('though', 1.0): 16,
#  ('suspect', 1.0): 3,
#  ('meant', 1.0): 2,
#  ('24', 1.0): 3,
#  ('hr', 1.0): 2,
#  ('touch', 1.0): 7,
#  ('kepler', 1.0): 3,
#  ('452b', 1.0): 4,
#  ('chalna', 1.0): 1,
#  ('hai', 1.0): 7,
#  ('thankyou', 1.0): 12,
#  ('hazel', 1.0): 1,
#  ('food', 1.0): 6,
#  ('brooklyn', 1.0): 1,
#  ('pta', 1.0): 2,
#  ('awak', 1.0): 8,
#  ('okayi', 1.0): 2,
#  ('awww', 1.0): 12,
#  ('ha', 1.0): 18,
#  ('doc', 1.0): 1,
#  ('splendid', 1.0): 1,
#  ('spam', 1.0): 1,
#  ('folder', 1.0): 1,
#  ('amount', 1.0): 1,
#  ('nigeria', 1.0): 1,
#  ('claim', 1.0): 1,
#  ('rted', 1.0): 1,
#  ('leg', 1.0): 3,
#  ('hurt', 1.0): 4,
#  ('bad', 1.0): 14,
#  ('mine', 1.0): 11,
#  ('saturday', 1.0): 5,
#  ('thaaank', 1.0): 1,
#  ('puhon', 1.0): 1,
#  ('happinesss', 1.0): 1,
#  ('tnc', 1.0): 1,
#  ('prior', 1.0): 1,
#  ('notif', 1.0): 2,
#  ('fat', 1.0): 1,
#  ('co', 1.0): 1,
#  ('probabl', 1.0): 7,
#  ('ate', 1.0): 4,
#  ('yuna', 1.0): 2,
#  ('tamesid', 1.0): 1,
#  ('´', 1.0): 3,
#  ('googl', 1.0): 5,
#  ('account', 1.0): 17,
#  ('scouser', 1.0): 1,
#  ('everyth', 1.0): 10,
#  ('zoe', 1.0): 1,
#  ('mate', 1.0): 5,
#  ('liter', 1.0): 5,
#  ("they'r", 1.0): 10,
#  ('samee', 1.0): 1,
#  ('edgar', 1.0): 1,
#  ('updat', 1.0): 12,
#  ('log', 1.0): 3,
#  ('bring', 1.0): 12,
#  ('abe', 1.0): 1,
#  ('meet', 1.0): 26,
#  ('x38', 1.0): 1,
#  ('sigh', 1.0): 3,
#  ('dreamili', 1.0): 1,
#  ('pout', 1.0): 1,
#  ('eye', 1.0): 12,
#  ('quacketyquack', 1.0): 6,
#  ('funni', 1.0): 15,
#  ('happen', 1.0): 13,
#  ('phil', 1.0): 1,
#  ('em', 1.0): 2,
#  ('del', 1.0): 1,
#  ('rodder', 1.0): 1,
#  ('els', 1.0): 8,
#  ('play', 1.0): 37,
#  ('newest', 1.0): 1,
#  ('gamejam', 1.0): 1,
#  ('irish', 1.0): 2,
#  ('literatur', 1.0): 2,
#  ('inaccess', 1.0): 2,
#  ("kareena'", 1.0): 2,
#  ('fan', 1.0): 21,
#  ('brain', 1.0): 10,
#  ('dot', 1.0): 8,
#  ('braindot', 1.0): 8,
#  ('fair', 1.0): 4,
#  ('rush', 1.0): 1,
#  ('either', 1.0): 10,
#  ('brandi', 1.0): 1,
#  ('18', 1.0): 5,
#  ('carniv', 1.0): 1,
#  ('men', 1.0): 8,
#  ('put', 1.0): 11,
#  ('mask', 1.0): 2,
#  ('xavier', 1.0): 1,
#  ('forneret', 1.0): 1,
#  ('jennif', 1.0): 1,
#  ('site', 1.0): 7,
#  ('free', 1.0): 31,
#  ('50.000', 1.0): 3,
#  ('8', 1.0): 10,
#  ('ball', 1.0): 7,
#  ('pool', 1.0): 5,
#  ('coin', 1.0): 5,
#  ('edit', 1.0): 6,
#  ('trish', 1.0): 1,
#  ('♥', 1.0): 13,
#  ('grate', 1.0): 5,
#  ('three', 1.0): 8,
#  ('comment', 1.0): 7,
#  ('wakeup', 1.0): 1,
#  ('besid', 1.0): 2,
#  ('dirti', 1.0): 2,
#  ('sex', 1.0): 4,
#  ('lmaooo', 1.0): 1,
#  ('😤', 1.0): 2,
#  ('loui', 1.0): 4,
#  ("he'", 1.0): 10,
#  ('throw', 1.0): 3,
#  ('caus', 1.0): 11,
#  ('inspir', 1.0): 6,
#  ('ff', 1.0): 40,
#  ('twoof', 1.0): 3,
#  ('gr8', 1.0): 1,
#  ('wkend', 1.0): 3,
#  ('kind', 1.0): 22,
#  ('exhaust', 1.0): 2,
#  ('word', 1.0): 17,
#  ('cheltenham', 1.0): 1,
#  ('area', 1.0): 4,
#  ('kale', 1.0): 1,
#  ('crisp', 1.0): 1,
#  ('ruin', 1.0): 5,
#  ('x37', 1.0): 1,
#  ('open', 1.0): 12,
#  ('worldwid', 1.0): 2,
#  ('outta', 1.0): 1,
#  ('sfvbeta', 1.0): 1,
#  ('vantast', 1.0): 1,
#  ('xcylin', 1.0): 1,
#  ('bundl', 1.0): 1,
#  ('show', 1.0): 20,
#  ('internet', 1.0): 2,
#  ('price', 1.0): 3,
#  ('realisticli', 1.0): 1,
#  ('pay', 1.0): 8,
#  ('net', 1.0): 1,
#  ('educ', 1.0): 1,
#  ('power', 1.0): 6,
#  ('weapon', 1.0): 1,
#  ('nelson', 1.0): 1,
#  ('mandela', 1.0): 1,
#  ('recent', 1.0): 8,
#  ('j', 1.0): 2,
#  ('chenab', 1.0): 1,
#  ('flow', 1.0): 5,
#  ('pakistan', 1.0): 1,
#  ('incredibleindia', 1.0): 1,
#  ('teenchoic', 1.0): 7,
#  ('choiceinternationalartist', 1.0): 7,
#  ('superjunior', 1.0): 7,
#  ('caught', 1.0): 4,
#  ('first', 1.0): 41,
#  ('salmon', 1.0): 1,
#  ('super-blend', 1.0): 1,
#  ('project', 1.0): 6,
#  ('youth@bipolaruk.org.uk', 1.0): 1,
#  ('awesom', 1.0): 35,
#  ('stream', 1.0): 12,
#  ('alma', 1.0): 1,
#  ('mater', 1.0): 1,
#  ('highschoolday', 1.0): 1,
#  ('clientvisit', 1.0): 1,
#  ('faith', 1.0): 3,
#  ('christian', 1.0): 1,
#  ('school', 1.0): 9,
#  ('lizaminnelli', 1.0): 1,
#  ('upcom', 1.0): 2,
#  ('uk', 1.0): 4,
#  ('😄', 1.0): 3,
#  ('singl', 1.0): 4,
#  ('hill', 1.0): 4,
#  ('everi', 1.0): 23,
#  ('beat', 1.0): 7,
#  ('wrong', 1.0): 9,
#  ('readi', 1.0): 22,
#  ('natur', 1.0): 1,
#  ('pefumeri', 1.0): 1,
#  ('workshop', 1.0): 2,
#  ('neal', 1.0): 1,
#  ('yard', 1.0): 1,
#  ('covent', 1.0): 1,
#  ('tomorrow', 1.0): 31,
#  ('fback', 1.0): 26,
#  ...}

# %%
def train_naive_bayes(freqs, train_x, train_y):
    
    vocab = set([pair[0] for pair in freqs.keys()])
    V = len(vocab)
    loglikelihood = {}
    # count N_pos and N_neg
    N_pos = N_neg = 0
    for pair in freqs.keys():
        if pair[1]>0:
            N_pos += freqs[pair]
        else:
            N_neg += freqs[pair]
    
    D = len(train_y)
    D_pos = sum(train_y)
    D_neg = D - D_pos

    logprior = np.log(D_pos) - np.log(D_neg)

    for word in vocab:
        freq_pos = freqs.get((word,1.0),0)
        freq_neg = freqs.get((word,0.0),0)
        p_w_pos = (freq_pos)+1/(N_pos+V)
        p_w_neg = (freq_neg)+1/(N_neg+V)
        loglikelihood[word] = np.log(p_w_pos) - np.log(p_w_neg)
    return logprior, loglikelihood

# %%
logprior, loglikelihood = train_naive_bayes(freqs, train_x, train_y)

# %%
len(loglikelihood)
# Out:
# 9091

# %%
loglikelihood
# Out:
# {'dose': -10.489494712712904,
#  'mixtur': -10.489494712712904,
#  '61': -10.489494712712904,
#  '2ish': 10.494712888195956,
#  '9-11': 10.494712888195956,
#  'teamzip': -10.489494712712904,
#  '9pm': 1.4482526596205106e-07,
#  'robinhood': -10.489494712712904,
#  'tama': -10.489494712712904,
#  'less': 0.6931425908643907,
#  'client_amends_edit': 10.494712888195956,
#  'clock': -0.6931331944252911,
#  'mypark': 11.593306625193023,
#  'suppos': 0.4054628253267776,
#  'morn': 1.0840126948661175,
#  '😘': 1.6092093435560173e-08,
#  'hind': -10.489494712712904,
#  '.\n.': -11.182628051963462,
#  '5878e503': 10.494712888195956,
#  'shock': -1.0985936887210854,
#  'mag': -11.182628051963462,
#  'art': 0.2231421961288511,
#  'rhi': 10.494712888195956,
#  'quickest': -10.489494712712904,
#  'milf': -10.489494712712904,
#  'context': 1.4482526596205106e-07,
#  'lit': -0.6931331944252911,
#  'custom': 1.386273635291035,
#  'hubba': -10.489494712712904,
#  'swipe': -10.489494712712904,
#  'bubbl': 1.0985938818223335,
#  'canon': 1.4482526596205106e-07,
#  "everything'": -10.489494712712904,
#  'semi': 10.494712888195956,
#  'uni': -11.182628051963462,
#  'sg': 1.4482526596205106e-07,
#  'airport': -1.2527530093148707,
#  'selo': 10.494712888195956,
#  'thumb': 10.494712888195956,
#  'jiba': 10.494712888195956,
#  'dash': -10.489494712712904,
#  'fennel': 10.494712888195956,
#  'crack': -0.6931331944252911,
#  'mayor': -10.489494712712904,
#  'cut': -1.8717903924611392,
#  'nalamannn': -10.489494712712904,
#  'uniqu': 0.6931334116641951,
#  'baechyyi': -10.489494712712904,
#  'yummm': 10.494712888195956,
#  'bookstor': 10.494712888195956,
#  'version': 0.6931425908643907,
#  'appl': 4.8275982100776105e-08,
#  'stationeri': 10.494712888195956,
#  'timw': -10.489494712712904,
#  '─': 12.574130080736968,
#  'stamina': 10.494712888195956,
#  "s'okay": 10.494712888195956,
#  'dipikirin': 10.494712888195956,
#  'kepler': 11.593306625193023,
#  'suffer': 11.593306625193023,
#  'buti': -10.489494712712904,
#  'rash': -10.489494712712904,
#  'pti': 10.494712888195956,
#  'anthem': 10.494712888195956,
#  'hahahaokay': -10.489494712712904,
#  'central': 11.187846155034885,
#  'everlast': 10.494712888195956,
#  'academ': -10.489494712712904,
#  'peregrin': -10.489494712712904,
#  'wong': -10.489494712712904,
#  'zephbot': 10.494712888195956,
#  'movement': -10.489494712712904,
#  'all': 10.494712888195956,
#  'weapon': -0.6931331944252911,
#  'holi': -10.489494712712904,
#  'cousin': 4.8275982100776105e-08,
#  'magpi': -10.489494712712904,
#  'sazbal': -10.489494712712904,
#  'ervin': -10.489494712712904,
#  'mbalula': 10.494712888195956,
#  'ouch': -0.40546042188215625,
#  'heal': 10.494712888195956,
#  'workhard': 10.494712888195956,
#  'nailedit': 10.494712888195956,
#  'long-dist': 10.494712888195956,
#  'tdc': -10.489494712712904,
#  'wellington': 10.494712888195956,
#  'shown': 10.494712888195956,
#  'fear': 1.4482526596205106e-07,
#  'taxi': 1.4482526596205106e-07,
#  '21st': -11.182628051963462,
#  'mo': 7.241363808585533e-08,
#  'arent': -10.489494712712904,
#  'seen': -0.9162879394256396,
#  'bo3': -10.489494712712904,
#  'privat': -0.6931331944252911,
#  'calibraskaep': -11.182628051963462,
#  'diseas': -11.182628051963462,
#  'cram': -10.489494712712904,
#  'unavail': -10.489494712712904,
#  'prolli': 10.494712888195956,
#  'mp3': 10.494712888195956,
#  'heyyy': -10.489494712712904,
#  'sloppi': 10.494712888195956,
#  'born': 1.4482526596205106e-07,
#  'gonna': -1.0115998015918577,
#  'sakin': 10.494712888195956,
#  'muahhh': 10.494712888195956,
#  'heart': -1.2992796044634,
#  'jisung': 10.494712888195956,
#  'whet': 10.494712888195956,
#  'feed': 0.28767980174468355,
#  'sold': -12.098910478960024,
#  'latepost': 10.494712888195956,
#  'idiot': 10.494712888195956,
#  'rrp': 10.494712888195956,
#  'champagn': 1.4482526596205106e-07,
#  'inatal': -10.489494712712904,
#  'rela': 10.494712888195956,
#  'degrassi': -10.489494712712904,
#  'über': -10.489494712712904,
#  'hol': -10.489494712712904,
#  'holborn': 10.494712888195956,
#  'ehm': 10.494712888195956,
#  'yey': 10.494712888195956,
#  'wheelchair': -10.489494712712904,
#  'nje': -10.489494712712904,
#  'heyi': -10.489494712712904,
#  'agent': 10.494712888195956,
#  'two': 0.14310056936631543,
#  'yippee': 10.494712888195956,
#  'cheesydelight': 10.494712888195956,
#  'carpet': 10.494712888195956,
#  'muddi': -10.489494712712904,
#  'fragment': -10.489494712712904,
#  'geneva': -10.489494712712904,
#  'chuckin': -10.489494712712904,
#  'bish': -11.182628051963462,
#  'leg': -0.287679717261631,
#  'ed': -12.098910478960024,
#  'everon': -10.489494712712904,
#  'macbook': 10.494712888195956,
#  'goodi': -10.489494712712904,
#  'ubericecream': -13.05441851683824,
#  'notic': -0.6931454322612418,
#  'बार': -10.489494712712904,
#  'indonesian': 10.494712888195956,
#  'exo': -11.182628051963462,
#  'sparki': 10.494712888195956,
#  'yeh': -10.489494712712904,
#  'vic': -10.489494712712904,
#  'freya': 10.494712888195956,
#  'ny': -11.182628051963462,
#  'kidney': -11.182628051963462,
#  'youth': 13.133744377889528,
#  "look'": 10.494712888195956,
#  'bonilla': 11.593306625193023,
#  'lsa': 10.494712888195956,
#  'fah': -10.489494712712904,
#  'cactu': -10.489494712712904,
#  'room': -0.8109263351404856,
#  'angi': -10.489494712712904,
#  'daredevil': 11.187846155034885,
#  'ur': 0.4228563533974423,
#  'broker': -10.489494712712904,
#  'abbymil': -11.182628051963462,
#  'charcoal': -10.489494712712904,
#  'ummm': -11.182628051963462,
#  'sengenza': -10.489494712712904,
#  '350': -10.489494712712904,
#  'pbr': -10.489494712712904,
#  'throw': 0.40546054257177644,
#  'enter': 2.197199986523614,
#  'jami': 10.494712888195956,
#  '2-3': 1.4482526596205106e-07,
#  'exit': -11.182628051963462,
#  'geez': -10.489494712712904,
#  '10:59': -10.489494712712904,
#  'easili': -0.6931331944252911,
#  'tramlin': 10.494712888195956,
#  'thick': 10.494712888195956,
#  'rid': -11.588088546259256,
#  'butter': 1.4482526596205106e-07,
#  'accommod': 10.494712888195956,
#  "attitude'": 10.494712888195956,
#  'fluent': -10.489494712712904,
#  'jennyjean': 1.4482526596205106e-07,
#  'beheaviour': -10.489494712712904,
#  'socent': 10.494712888195956,
#  '😓': -11.182628051963462,
#  'darren': -11.182628051963462,
#  'eldest': -10.489494712712904,
#  'bag': -0.4054627649816043,
#  'sjw': 10.494712888195956,
#  'squat': 10.494712888195956,
#  'wew': -10.489494712712904,
#  'predict': -10.489494712712904,
#  'zayniscomingback': -11.588088546259256,
#  'drove': -10.489494712712904,
#  'bcz': -10.489494712712904,
#  'trend': -0.6931401874197693,
#  'winter': -1.0985936887210854,
#  'cd': -10.489494712712904,
#  'bye': -0.18232060505982361,
#  'fenja': 10.494712888195956,
#  'burdensom': -10.489494712712904,
#  'kita': -11.182628051963462,
#  'hiya': 1.0985938818223335,
#  '72': -11.588088546259256,
#  'omar': 10.494712888195956,
#  'funer': -11.875768311796868,
#  'men': 12.574130080736968,
#  'melbourn': -10.489494712712904,
#  'heswifi': 10.494712888195956,
#  'kaya': -11.182628051963462,
#  'aisyhhh': -10.489494712712904,
#  'accord': 10.494712888195956,
#  'overwhelm': -10.489494712712904,
#  'gurgaon': -10.489494712712904,
#  'x23': 10.494712888195956,
#  '404': -10.489494712712904,
#  '45': -10.489494712712904,
#  'punt': 10.494712888195956,
#  'tree': -0.40546042188215625,
#  'mastership': 10.494712888195956,
#  '2hour': -10.489494712712904,
#  'elizabetholsen': 10.494712888195956,
#  'nvr': -10.489494712712904,
#  'letter': 0.6931334116641951,
#  'nicki': -10.489494712712904,
#  'chloe': 7.241363808585533e-08,
#  "o'clock": 10.494712888195956,
#  'steel': 1.4482526596205106e-07,
#  'feb': 10.494712888195956,
#  'mashaket': -10.489494712712904,
#  'wareh': 10.494712888195956,
#  'breach': 10.494712888195956,
#  'upsid': 10.494712888195956,
#  'knew': 0.3364706754217628,
#  'rumor': -11.588088546259256,
#  'true': 7.622582565147695e-09,
#  'reh': 10.494712888195956,
#  '¦': 10.494712888195956,
#  'experttradesmen': 10.494712888195956,
#  'demo': 11.187846155034885,
#  'ubud': 10.494712888195956,
#  'tast': 11.880986378661724,
#  '🎂': -10.489494712712904,
#  'gua': -10.489494712712904,
#  'funcionar': 10.494712888195956,
#  'acorn': 10.494712888195956,
#  'burnt': 1.4482526596205106e-07,
#  'annual': 10.494712888195956,
#  'rp': 1.4482526596205106e-07,
#  'grepe': -10.489494712712904,
#  'lipstick': -10.489494712712904,
#  'gent': 10.494712888195956,
#  'duke': 11.187846155034885,
#  'jcreport': 10.494712888195956,
#  'slack': 1.4482526596205106e-07,
#  'rare': 1.4482526596205106e-07,
#  'taybigail': -10.489494712712904,
#  'paul': 0.6931334116641951,
#  'motor': -10.489494712712904,
#  'eat': -1.7491941014441397,
#  'jlover': 10.494712888195956,
#  'ripstegi': -10.489494712712904,
#  'depress': -11.875768311796868,
#  '더쇼': -11.588088546259256,
#  'refer': 10.494712888195956,
#  'wardrob': 0.6931334116641951,
#  'hanbin': 10.494712888195956,
#  'beautiful': 10.494712888195956,
#  'ultor': 10.494712888195956,
#  'genuin': -11.182628051963462,
#  'inbox': 10.494712888195956,
#  'thoracicbridg': 10.494712888195956,
#  '05.15': -10.489494712712904,
#  'gather': -10.489494712712904,
#  'hire': 10.494712888195956,
#  '6g': -10.489494712712904,
#  'lune': -10.489494712712904,
#  'bissmillah': 10.494712888195956,
#  'dd': 1.4482526596205106e-07,
#  'remov': 0.40546054257177644,
#  'illustr': 10.494712888195956,
#  'destin': -10.489494712712904,
#  'rapunzel': 10.494712888195956,
#  'ksoo': -10.489494712712904,
#  'awel': -10.489494712712904,
#  'brasileirao': -10.489494712712904,
#  '30th': 1.4482526596205106e-07,
#  'area': 1.386273635291035,
#  'D;': -10.489494712712904,
#  'rlli': -10.489494712712904,
#  'suckmejimin': -10.489494712712904,
#  'nonscript': 10.494712888195956,
#  'yess': -0.6931331944252911,
#  'dump': 10.494712888195956,
#  'pamuk': 10.494712888195956,
#  'infrastructur': -11.182628051963462,
#  "doedn't": -10.489494712712904,
#  'yk': -10.489494712712904,
#  'ebook': -10.489494712712904,
#  'ramadhan': -10.489494712712904,
#  'pregnanc': -10.489494712712904,
#  '144p': -10.489494712712904,
#  'pleas': -1.111034574739043,
#  'empow': 10.494712888195956,
#  'embrac': 10.494712888195956,
#  'crime': -10.489494712712904,
#  'nacho': -10.489494712712904,
#  'helsinki': 10.494712888195956,
#  'vomit': -10.489494712712904,
#  'aug': 1.0985938818223335,
#  'offici': 0.9808235038199262,
#  'laid': 0.6931334116641951,
#  'yeap': 10.494712888195956,
#  'nextweek': 10.494712888195956,
#  'cinema': -11.875768311796868,
#  'accept': -0.6931331944252911,
#  'basketbal': 10.494712888195956,
#  'orlean': 10.494712888195956,
#  'afang': 11.187846155034885,
#  'choroo': 10.494712888195956,
#  'look': 0.32189993464494115,
#  'mask': 11.187846155034885,
#  'theori': 1.4482526596205106e-07,
#  '9:30': -10.489494712712904,
#  'leannerin': 1.4482526596205106e-07,
#  'everett': 10.494712888195956,
#  "it'okay": -10.489494712712904,
#  "microsoft'": -10.489494712712904,
#  'aidzin': 10.494712888195956,
#  'pa-copi': -10.489494712712904,
#  'storifi': -10.489494712712904,
#  'smf': 10.494712888195956,
#  'homosexu': 10.494712888195956,
#  'foodi': 10.494712888195956,
#  'manila_bro': 10.494712888195956,
#  'bapu': 10.494712888195956,
#  'cwnt': -10.489494712712904,
#  'masaantoday': 11.880986378661724,
#  'bodo': -10.489494712712904,
#  'window': 0.5596128425849174,
#  'toss': 1.4482526596205106e-07,
#  'd1': -10.489494712712904,
#  'cimbom': 10.494712888195956,
#  "when'": -10.489494712712904,
#  'fcking': -10.489494712712904,
#  'without': -0.7985059883787349,
#  'photocard': -10.489494712712904,
#  'conni': 11.187846155034885,
#  'katmtan': 10.494712888195956,
#  'stream': -0.5596147871826522,
#  'thq': 10.494712888195956,
#  'eleph': 10.494712888195956,
#  'reign': -10.489494712712904,
#  'aval': -10.489494712712904,
#  'mz': 10.494712888195956,
#  'sf': -0.6931331944252911,
#  'wz': 10.494712888195956,
#  'potato': -10.489494712712904,
#  'ramo': -10.489494712712904,
#  'haveagoodday': 10.494712888195956,
#  'despond': 10.494712888195956,
#  'public': 1.0985938818223335,
#  'otwolgrandtrail': 0.40546054257177644,
#  'useless': 0.6931334116641951,
#  'space': -1.3862734542586985,
#  'trespass': -10.489494712712904,
#  'tmrw': 11.187846155034885,
#  'michel': 10.494712888195956,
#  'tweetland': 10.494712888195956,
#  'ahahah': 1.4482526596205106e-07,
#  'marriag': 10.494712888195956,
#  'cyber': 1.4482526596205106e-07,
#  'بندر': 10.494712888195956,
#  'log': 1.0985938818223335,
#  'maryhick': 10.494712888195956,
#  'emesh': 10.494712888195956,
#  'chem': -11.182628051963462,
#  "horton'": -10.489494712712904,
#  'm20': -10.489494712712904,
#  'eas': 10.494712888195956,
#  'mysql': -10.489494712712904,
#  'subject': 12.28644916778143,
#  'enn': 10.494712888195956,
#  'chinua': 10.494712888195956,
#  'vike': 10.494712888195956,
#  'arummzz': 11.187846155034885,
#  'mush': -10.489494712712904,
#  'stun': 1.0985938818223335,
#  'chosen': 10.494712888195956,
#  'jelous': -10.489494712712904,
#  'viewer': -10.489494712712904,
#  'inner': 11.187846155034885,
#  'seed': 11.593306625193023,
#  'car': -0.7884543114259852,
#  'mixcloud': 10.494712888195956,
#  'legsupthewal': 10.494712888195956,
#  'murugan': -10.489494712712904,
#  'x37': 10.494712888195956,
#  'daw': -0.6931331944252911,
#  'livi': 10.494712888195956,
#  'etienn': -10.489494712712904,
#  'jame': 0.8472926081225305,
#  'right': -0.07598584986141477,
#  'tarryn': 10.494712888195956,
#  'learnt': 10.494712888195956,
#  'justic': 1.4482526596205106e-07,
#  'osea': -10.489494712712904,
#  'mehtab': 10.494712888195956,
#  'recal': -11.182628051963462,
#  'fought': 10.494712888195956,
#  'whistl': -10.489494712712904,
#  'x27': 10.494712888195956,
#  'mango': 1.4482526596205106e-07,
#  'file': -0.6931331944252911,
#  'singl': 0.6931402960404779,
#  'wth': -11.182628051963462,
#  'rakna': 10.494712888195956,
#  'beme': 10.494712888195956,
#  'som': 1.4482526596205106e-07,
#  'jst': 10.494712888195956,
#  'lorenangel': 10.494712888195956,
#  'follow': 0.26393286648267456,
#  'surajettan': 10.494712888195956,
#  'gleam': 10.494712888195956,
#  'ughh': -10.489494712712904,
#  'multiraci': 10.494712888195956,
#  'edel': -10.489494712712904,
#  'fit': 7.241363808585533e-08,
#  'fahrinahmad': 10.494712888195956,
#  'fuse': -10.489494712712904,
#  'hike': -10.489494712712904,
#  'webz': 10.494712888195956,
#  'debat': 11.187846155034885,
#  'tline': -10.489494712712904,
#  'randi': 10.494712888195956,
#  'leo': 10.494712888195956,
#  'psychopath': 10.494712888195956,
#  'hoe': -10.489494712712904,
#  'imysm': -11.182628051963462,
#  'frnd': 10.494712888195956,
#  'photo': 0.37469267204053347,
#  'cushion': 10.494712888195956,
#  'waiter': 10.494712888195956,
#  'a9': -11.182628051963462,
#  'breconbeacon': -10.489494712712904,
#  'notion': 1.4482526596205106e-07,
#  'act': 1.098603085160185,
#  'lyin': -10.489494712712904,
#  'uncut': 10.494712888195956,
#  'ili': 11.593306625193023,
#  'keep': 0.5733455937054037,
#  'scar': 10.494712888195956,
#  'tip': 1.386273635291035,
#  'laugh': -0.18232060505982361,
#  'boredom': -10.489494712712904,
#  'wiv': -10.489494712712904,
#  'hozier': -10.489494712712904,
#  'saddest': -11.182628051963462,
#  "sacconejoly'": -10.489494712712904,
#  'yeah': -0.15415054317500188,
#  "here'": 13.490418725514493,
#  'put': 0.09530994130585979,
#  '510': -10.489494712712904,
#  'nap': 0.40546054257177644,
#  'parti': -0.3184527692725232,
#  'kick': -11.588088546259256,
#  'woke': -1.4663299223030009,
#  'ti5': 1.4482526596205106e-07,
#  'yellow': 11.187846155034885,
#  'memem': -10.489494712712904,
#  'tito': -10.489494712712904,
#  'replenish': 10.494712888195956,
#  'kayo': -10.489494712712904,
#  'treat': -0.22314213095608415,
#  'let': 0.6090636585543665,
#  'dartmoor': 10.494712888195956,
#  '873': -10.489494712712904,
#  'bakar': -10.489494712712904,
#  'sodder': -10.489494712712904,
#  'dipsatch': 10.494712888195956,
#  '5word': 11.187846155034885,
#  'stark': 10.494712888195956,
#  'emyu': -10.489494712712904,
#  'fond': 10.494712888195956,
#  'cri': -1.691672763751971,
#  'bip': 10.494712888195956,
#  'greater': 10.494712888195956,
#  'unagi': -10.489494712712904,
#  'pop': 0.5108219616664642,
#  'shoulder': -0.6931331944252911,
#  'dy': -10.489494712712904,
#  'elfindelmundo': 1.4482526596205106e-07,
#  'hoki': 10.494712888195956,
#  'stat': 14.426511238932012,
#  'lineup': 10.494712888195956,
#  'chanhun': 10.494712888195956,
#  'matern': -10.489494712712904,
#  'secondari': -10.489494712712904,
#  'island': 0.6931334116641951,
#  'miser': -11.182628051963462,
#  'mwf': 10.494712888195956,
#  'sxrew': -10.489494712712904,
#  'cooki': 1.4482526596205106e-07,
#  'paramed': -10.489494712712904,
#  'li': -10.489494712712904,
#  'flavour': -10.489494712712904,
#  'river': 11.593306625193023,
#  'bakit': -11.875768311796868,
#  'burfday': 10.494712888195956,
#  'baon': -10.489494712712904,
#  'clapham': -10.489494712712904,
#  'per': 10.494712888195956,
#  'unvarnish': 10.494712888195956,
#  'fruit': 0.6931402960404779,
#  'escap': 0.6931334116641951,
#  'v.ball': 10.494712888195956,
#  'sonaaa': 10.494712888195956,
#  'lyric': -10.489494712712904,
#  'imitatia': 10.494712888195956,
#  '10:17': 10.494712888195956,
#  'aaron': -10.489494712712904,
#  'hotscratch': -10.489494712712904,
#  'zonzofox': 11.187846155034885,
#  '87': 10.494712888195956,
#  'perform': -1.2527530093148707,
#  'yt': -0.40546042188215625,
#  'there': -0.6931401874197693,
#  'shem': -11.182628051963462,
#  'tx': 11.187846155034885,
#  'varsiti': -10.489494712712904,
#  'philippin': 11.187846155034885,
#  'bc': -1.7176482314756272,
#  'semo': 11.187846155034885,
#  'yall': 1.4482526596205106e-07,
#  'catch': 0.2513135655445482,
#  'viabl': 10.494712888195956,
#  'knockin': -10.489494712712904,
#  'ljp': -10.489494712712904,
#  'gol': -10.489494712712904,
#  'skip': -10.489494712712904,
#  'aki': 10.494712888195956,
#  'portug': 10.494712888195956,
#  'spanner': 10.494712888195956,
#  'sleepi': -11.588088546259256,
#  'forc': 7.241363808585533e-08,
#  'thaaat': -10.489494712712904,
#  '4:13': 10.494712888195956,
#  'bodi': 0.08701117933805147,
#  'recit': 11.187846155034885,
#  'tend': 1.4482526596205106e-07,
#  'carri': 11.187846155034885,
#  'hangout': -11.182628051963462,
#  'sarah': 11.880986378661724,
#  'diagnos': -10.489494712712904,
#  'ｍｅ': -14.044815882340032,
#  'lol': 0.43721349316720737,
#  'incl': -11.182628051963462,
#  'reader': 11.880986378661724,
#  'mate': 0.9162824559622585,
#  'stoke': 10.494712888195956,
#  'soniii': -10.489494712712904,
#  'suicid': 10.494712888195956,
#  'hoya': -11.588088546259256,
#  'tent': 11.187846155034885,
#  'askaman': 10.494712888195956,
#  'usa': 1.0985938818223335,
#  'lahhh': -10.489494712712904,
#  'outi': 11.187846155034885,
#  'pierojogg': 10.494712888195956,
#  'dick': -11.588088546259256,
#  'qt': -10.489494712712904,
#  'fandom': 0.40546054257177644,
#  'unpar': -10.489494712712904,
#  'yuppiiee': 10.494712888195956,
#  'x2': 10.494712888195956,
#  'disciplin': -11.182628051963462,
#  'koffi': 10.494712888195956,
#  'a7la': 10.494712888195956,
#  'delici': 11.593306625193023,
#  'unabl': -11.182628051963462,
#  'buddi': 1.2527531024183247,
#  'spend': -1.7917362554473732,
#  'xst': 10.494712888195956,
#  'aaj': -10.489494712712904,
#  'lloyd': -10.489494712712904,
#  'incred': 12.104128538583506,
#  'muntu': 10.494712888195956,
#  'tommarow': 10.494712888195956,
#  'chronicl': 11.593306625193023,
#  'otherwis': 0.5108219616664642,
#  'flip': -1.3862734542586985,
#  'casilla': -10.489494712712904,
#  'fur-trim': -10.489494712712904,
#  'sturdi': 10.494712888195956,
#  'dan': 1.0985938818223335,
#  '⅛': 10.494712888195956,
#  'alter': 1.4482526596205106e-07,
#  'mull': 10.494712888195956,
#  '7am': 1.4482526596205106e-07,
#  'onyu': 10.494712888195956,
#  'buzz': 11.187846155034885,
#  'oss': 10.494712888195956,
#  'wh': -10.489494712712904,
#  'jotzh': 10.494712888195956,
#  'sorri': -2.197222673329834,
#  'slip': 10.494712888195956,
#  'wesen': -10.489494712712904,
#  'finddjderek': -10.489494712712904,
#  'bea': -10.489494712712904,
#  'wa': -10.489494712712904,
#  'poison': -11.588088546259256,
#  'naaan': -10.489494712712904,
#  'xfile': 10.494712888195956,
#  'fenestoscop': -10.489494712712904,
#  'whammi': -10.489494712712904,
#  'problemmm': 10.494712888195956,
#  'dum': 11.187846155034885,
#  'lisa': 11.187846155034885,
#  'somi': 10.494712888195956,
#  'timog': 10.494712888195956,
#  'nooo': -12.79205489121211,
#  'ob': -10.489494712712904,
#  'fool': -10.489494712712904,
#  'thaaank': 10.494712888195956,
#  '{:': -10.489494712712904,
#  'gamer': 10.494712888195956,
#  'demand': 11.187846155034885,
#  'para': 10.494712888195956,
#  'talk-kama': -10.489494712712904,
#  'mussel': 10.494712888195956,
#  'app': 1.206907906947663e-08,
#  'happyalien': 10.494712888195956,
#  'dia': -0.6931331944252911,
#  'hahahahahaah': -10.489494712712904,
#  'bitchfac': 10.494712888195956,
#  'mosqu': -10.489494712712904,
#  'und': 10.494712888195956,
#  'ey': 10.494712888195956,
#  'spanish': 0.6931334116641951,
#  'falco': 10.494712888195956,
#  'everybodi': -1.3862734542586985,
#  'process': 11.880986378661724,
#  'ps4': -11.588088546259256,
#  'action': 1.4482526596205106e-07,
#  'icu': -10.489494712712904,
#  'play': -0.05264369120220325,
#  'hall': 1.4482526596205106e-07,
#  'mare': -10.489494712712904,
#  'subtitl': -10.489494712712904,
#  'auspost': 10.494712888195956,
#  'logic': 10.494712888195956,
#  'sadli': -2.3025600336739402,
#  'fast': -1.098602988608444,
#  'leftov': -11.182628051963462,
#  'oven': 11.187846155034885,
#  'unknown': -0.6931331944252911,
#  'evan': -10.489494712712904,
#  'sararoc': -10.489494712712904,
#  '111': 1.4482526596205106e-07,
#  '317': -10.489494712712904,
#  'mel': -10.489494712712904,
#  'grabe': -11.875768311796868,
#  'cosplayprogress': 10.494712888195956,
#  'gif': -10.489494712712904,
#  'valuabl': 10.494712888195956,
#  '5s': -10.489494712712904,
#  'loveyaaah': 10.494712888195956,
#  'distress': -10.489494712712904,
#  'addmeonsnapchat': -0.6931331944252911,
#  'webcamsex': -11.588088546259256,
#  'x': 0.3566747095509597,
#  'mahnor': 10.494712888195956,
#  'goodtim': 10.494712888195956,
#  'concern': -0.6931331944252911,
#  'web': 0.6931402960404779,
#  'parisa': 10.494712888195956,
#  'tirth': 10.494712888195956,
#  'warnaaa': -10.489494712712904,
#  'twitter': 0.22314328027578423,
#  'ps3': 1.4482526596205106e-07,
#  'avoid': -11.182628051963462,
#  'girli': 10.494712888195956,
#  'sn16': 10.494712888195956,
#  '838': 10.494712888195956,
#  'gaaawd': -10.489494712712904,
#  'cantik': 10.494712888195956,
#  'describ': -10.489494712712904,
#  'exam': 3.620707045293159e-08,
#  'kindli': 11.187846155034885,
#  'blarney': 10.494712888195956,
#  'buuut': 1.4482526596205106e-07,
#  'chalna': 10.494712888195956,
#  'twoof': 11.593306625193023,
#  'tgk': -10.489494712712904,
#  'sorrri': -10.489494712712904,
#  'greysonch': -10.489494712712904,
#  'cat': -0.8754654786949576,
#  '️': -0.08701115410270699,
#  'cam': 11.593306625193023,
#  'tori': 10.494712888195956,
#  'kiss': -0.287679717261631,
#  'vega': 0.40546054257177644,
#  'zoom': -10.489494712712904,
#  "stomach'": -10.489494712712904,
#  'feetblog': 11.187846155034885,
#  'peyton': 10.494712888195956,
#  'johnyherbert': 10.494712888195956,
#  'derbi': -10.489494712712904,
#  'x5': 10.494712888195956,
#  'anticip': 10.494712888195956,
#  'abandon': 1.4482526596205106e-07,
#  'bir': 10.494712888195956,
#  '1/2': -1.0985936887210854,
#  'stephani': 11.187846155034885,
#  'servicewithasmil': 10.494712888195956,
#  'skype': -0.6931425184503057,
#  'ivypowel': 10.494712888195956,
#  'yaad': 10.494712888195956,
#  'hoxton': 10.494712888195956,
#  'tompolo': 10.494712888195956,
#  '--->': 10.494712888195956,
#  'the_madstork': 10.494712888195956,
#  'margo': -10.489494712712904,
#  'deennya': 10.494712888195956,
#  '343': -10.489494712712904,
#  'safer': -10.489494712712904,
#  'bethesda': -10.489494712712904,
#  'chrome': 10.494712888195956,
#  'luv': 0.6931402960404779,
#  'mirror': 1.0985938818223335,
#  'hood': 10.494712888195956,
#  ':-)': 16.79179443174292,
#  'tix': 11.187846155034885,
#  'suay': -10.489494712712904,
#  'anywayhedidanicejob': -10.489494712712904,
#  "angelo'": -10.489494712712904,
#  'ae': -10.489494712712904,
#  'queen': 0.6931425908643907,
#  'zareen': 10.494712888195956,
#  'gun': 11.187846155034885,
#  'stool': 10.494712888195956,
#  'nawf': -10.489494712712904,
#  '》': -15.836574692444735,
#  'provok': 10.494712888195956,
#  'definit': 2.3025726428932463,
#  'steal': -10.489494712712904,
#  'togeth': 2.4138102849846632e-08,
#  'school': -0.8938160423505281,
#  'koel': 10.494712888195956,
#  'adf': 10.494712888195956,
#  'pegel': 10.494712888195956,
#  'goddess': 10.494712888195956,
#  'amb': -10.489494712712904,
#  'hypercholesteloremia': -10.489494712712904,
#  'juggl': 10.494712888195956,
#  'lamon': -10.489494712712904,
#  'left': -0.788455835892047,
#  'six': 10.494712888195956,
#  'kitten': 10.494712888195956,
#  'truthfulwordsof': 10.494712888195956,
#  'avoplex': 10.494712888195956,
#  'itter': 10.494712888195956,
#  'indirect': 10.494712888195956,
#  'fanboy': 10.494712888195956,
#  'msg': 0.6931334116641951,
#  'gurli': -10.489494712712904,
#  'agov': -10.489494712712904,
#  'leno': -10.489494712712904,
#  'unlik': -11.182628051963462,
#  'buffer': 7.241363808585533e-08,
#  'highlight': -10.489494712712904,
#  'dunedin': 10.494712888195956,
#  'housemus': 11.593306625193023,
#  'gari': 10.494712888195956,
#  'commit': -11.182628051963462,
#  'choreograph': -10.489494712712904,
#  'cag': -10.489494712712904,
#  "dongwoo'": 10.494712888195956,
#  'tebrik': 10.494712888195956,
#  'end': -1.018568209357027,
#  'mixtap': -11.182628051963462,
#  'bahari': 10.494712888195956,
#  'america': 1.4482526596205106e-07,
#  '11pm': 10.494712888195956,
#  'fuzzi': -10.489494712712904,
#  'appar': 0.2231421961288511,
#  'njoy': 10.494712888195956,
#  'terrif': 10.494712888195956,
#  'john': 12.28644916778143,
#  'uwes': -10.489494712712904,
#  'appeal': 1.4482526596205106e-07,
#  'okok': 10.494712888195956,
#  'upp': 0.6931334116641951,
#  'sharp': 11.187846155034885,
#  'rumbel': -10.489494712712904,
#  'siriu': -10.489494712712904,
#  'child': 0.40546054257177644,
#  'whatthefuck': -10.489494712712904,
#  'noesss': -10.489494712712904,
#  'ifc': 10.494712888195956,
#  'edit': 0.4054628253267776,
#  'cuticl': 10.494712888195956,
#  'tumor': -10.489494712712904,
#  'jd': 10.494712888195956,
#  'sumer': -10.489494712712904,
#  'ex': 11.187846155034885,
#  'record': 0.28767980174468355,
#  'goin': 1.4482526596205106e-07,
#  'taknottem': -10.489494712712904,
#  'bhook': -10.489494712712904,
#  'huhuhu': -10.489494712712904,
#  'moan': 10.494712888195956,
#  'banter': 10.494712888195956,
#  'juicebro': 10.494712888195956,
#  'password': 1.4482526596205106e-07,
#  'pin': 1.386273635291035,
#  'hammi': 10.494712888195956,
#  'wah': 0.6931334116641951,
#  'wena': -10.489494712712904,
#  'lootcrat': -10.489494712712904,
#  '2.25': 10.494712888195956,
#  'semest': -11.182628051963462,
#  'sleeep': -11.588088546259256,
#  'dessert': -11.182628051963462,
#  'idol': 0.40546054257177644,
#  'orang': -11.182628051963462,
#  'polic': -11.182628051963462,
#  'ry': -10.489494712712904,
#  '👓': 10.494712888195956,
#  "kath'd": -10.489494712712904,
#  'meaningless': 10.494712888195956,
#  'ouh': -10.489494712712904,
#  'minju': 10.494712888195956,
#  'socket': 10.494712888195956,
#  'hellooo': 10.494712888195956,
#  'giachietittiwed': -10.489494712712904,
#  'kinick': 10.494712888195956,
#  'cash': -10.489494712712904,
#  'blame': 1.4482526596205106e-07,
#  'candi': 7.241363808585533e-08,
#  'pilllow': -10.489494712712904,
#  'war': -10.489494712712904,
#  'sunnyday': 10.494712888195956,
#  'parasyt': -10.489494712712904,
#  'tempor': 10.494712888195956,
#  '♬': 10.494712888195956,
#  'msnbc': -10.489494712712904,
#  'siddi': 10.494712888195956,
#  'protein': -10.489494712712904,
#  'kiksext': 3.620707045293159e-08,
#  'chateau': 10.494712888195956,
#  'tdif': 10.494712888195956,
#  'degener': 10.494712888195956,
#  'vacat': 0.9162824559622585,
#  'can': -10.489494712712904,
#  'lorm': -10.489494712712904,
#  "athena'": 10.494712888195956,
#  'gn': 0.6931334116641951,
#  '15th': 11.187846155034885,
#  'unit': 4.8275982100776105e-08,
#  'spam': -1.6094156214218531,
#  'heel': 11.187846155034885,
#  'helen': 11.187846155034885,
#  'alien': -10.489494712712904,
#  'gut': -12.79205489121211,
#  '😔': -12.281231112985544,
#  "sterling'": -10.489494712712904,
#  'kahaaa': -10.489494712712904,
#  'mar': 10.494712888195956,
#  'slow': -1.3862839075984847,
#  'nash': 1.4482526596205106e-07,
#  'tammirossm': -11.875768311796868,
#  'goodmus': -11.588088546259256,
#  'feder': 10.494712888195956,
#  'kme': -10.489494712712904,
#  'luck': 1.6486541592719992,
#  'lew': -10.489494712712904,
#  'tumour': -10.489494712712904,
#  'muv': -10.489494712712904,
#  '22stan': -10.489494712712904,
#  'horni': -11.182628051963462,
#  '🙅': 10.494712888195956,
#  'gail': 10.494712888195956,
#  'aint': -1.6094156214218531,
#  'hiii': 11.187846155034885,
#  'food': -0.6931448494970311,
#  'babysit': -10.489494712712904,
#  'hack': -1.9458862761537998,
#  'goy': -10.489494712712904,
#  'scam': 10.494712888195956,
#  'wrote': 4.8275982100776105e-08,
#  'sheeran': -10.489494712712904,
#  'via': 4.094317343212013,
#  'salamat': 10.494712888195956,
#  'tradetalk': 10.494712888195956,
#  'ooop': -10.489494712712904,
#  'scottish': -10.489494712712904,
#  'ucount': 10.494712888195956,
#  'home-bas': 10.494712888195956,
#  'realisticli': 10.494712888195956,
#  'pledg': -10.489494712712904,
#  'bottom': 0.6931334116641951,
#  'tud': 10.494712888195956,
#  'mapl': 11.187846155034885,
#  'mice': 10.494712888195956,
#  '4.4+': -10.489494712712904,
#  'rain': -0.6931464035371753,
#  '2009': 1.4482526596205106e-07,
#  'arian': -10.489494712712904,
#  'tridon': 10.494712888195956,
#  'ii': -10.489494712712904,
#  'enjoy': 2.0971376522559306,
#  '1,300': -10.489494712712904,
#  'facetim': 3.620707045293159e-08,
#  'sausag': -10.489494712712904,
#  'shouldv': -10.489494712712904,
#  'se': 0.6931334116641951,
#  'hallyu': -10.489494712712904,
#  '🇷': 10.494712888195956,
#  'apink': -11.588088546259256,
#  'chocol': 2.4138102849846632e-08,
#  ';)': 13.585728778827972,
#  'iyalaya': -10.489494712712904,
#  '120': 0.6931334116641951,
#  'niaaa': -10.489494712712904,
#  'lagiii': 10.494712888195956,
#  'begin': 0.6931402960404779,
#  'thug': 10.494712888195956,
#  'disc': 1.4482526596205106e-07,
#  'leeteuk': 10.494712888195956,
#  '4': 0.2719333104286088,
#  '1-0': -10.489494712712904,
#  'typic': 7.241363808585533e-08,
#  '777x': 10.494712888195956,
#  'stupid': -0.5596127856880309,
#  'guzel': 10.494712888195956,
#  'eric': 0.6931334116641951,
#  'music': 0.22314309958387657,
#  'pebbl': 10.494712888195956,
#  'takraw': -10.489494712712904,
#  'auvssscr': 10.494712888195956,
#  'charl': 1.4482526596205106e-07,
#  'للعودة': 10.494712888195956,
#  'burket': 10.494712888195956,
#  'fl': 10.494712888195956,
#  'bt': -1.3862734542586985,
#  'lifetim': -10.489494712712904,
#  'welsh': 1.4482526596205106e-07,
#  'bitsy@bitdefender.com': 10.494712888195956,
#  'u21': 10.494712888195956,
#  'wasnt': 1.4482526596205106e-07,
#  '6th': -10.489494712712904,
#  'phil': 10.494712888195956,
#  'nutshel': 10.494712888195956,
#  'know.for': -10.489494712712904,
#  'tmw': -10.489494712712904,
#  'intent': -10.489494712712904,
#  'setup': 10.494712888195956,
#  'artworkbyli': 10.494712888195956,
#  'valu': 11.187846155034885,
#  'sent': -0.133530877593798,
#  'portsmouth': 10.494712888195956,
#  'gentlemen': 10.494712888195956,
#  'z': -11.588088546259256,
#  'homo': -11.182628051963462,
#  'steroid': 10.494712888195956,
#  'made': 0.5930631360726424,
#  '975-580-': 10.494712888195956,
#  'obv': 10.494712888195956,
#  'lolll': 10.494712888195956,
#  'nowt': -10.489494712712904,
#  'vinni': 10.494712888195956,
#  'wowww': 11.187846155034885,
#  'doc': 10.494712888195956,
#  'apt': -10.489494712712904,
#  'hastili': 10.494712888195956,
#  'tgp': 10.494712888195956,
#  'wub': 10.494712888195956,
#  'dunwan': -10.489494712712904,
#  'ff': 2.3025788679199395,
#  'unlist': 10.494712888195956,
#  "what'": 0.07410783039350388,
#  'soln': -10.489494712712904,
#  'hound': 10.494712888195956,
#  '🔥': 10.494712888195956,
#  'arriv': 2.656750474151032,
#  'oili': 10.494712888195956,
#  'goa': -10.489494712712904,
#  'akooo': -10.489494712712904,
#  'confirm': 11.593306625193023,
#  'chanel': -10.489494712712904,
#  'contempl': 10.494712888195956,
#  'uk': -0.4054627649816043,
#  'nigeria': 10.494712888195956,
#  'frightl': 10.494712888195956,
#  ...}

# %%
def sentiment_predictor(tweet, logprior, loglikelihood):
    words_in_tweet = clean_tweet(tweet)
    
    p=logprior
    
    for word in words_in_tweet:
        if word in loglikelihood:
            p += loglikelihood[word]
    if p>1:
        sentiment='positive'
    else:
        sentiment='negative'
    return sentiment

# %%
my_tweet = 'I am very happy today'
p = sentiment_predictor(my_tweet, logprior, loglikelihood)
print('The expected output is', p)
# Out:
# The expected output is positive
