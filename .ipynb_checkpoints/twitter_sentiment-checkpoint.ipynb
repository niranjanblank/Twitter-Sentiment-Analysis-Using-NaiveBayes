# %%
from nltk.corpus import stopwords, twitter_samples
from nltk.stem import PorterStemmer
import re
import numpy as np
import pandas as pd
import string
import nltk
from nltk.tokenize import TweetTokenizer

# %%
#getting the positive and negative tweets
positive_tweets = twitter_samples.strings('positive_tweets.json')
negative_tweets = twitter_samples.strings('negative_tweets.json')

# %%
#split data for training and testing
train_positive = positive_tweets[:4000]
test_positive = positive_tweets[4000:]

train_negative = negative_tweets[:4000]
test_negative = negative_tweets[4000:]

train_x = train_positive + train_negative
test_x = test_positive + test_negative

train_y = np.append(np.ones(len(train_positive)), np.zeros(len(train_negative)))
test_y = np.append(np.ones(len(test_positive)), np.zeros(len(test_negative)))

# %%
train_positive[0:10]
# Out:
# ['#FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)',
#  '@Lamb2ja Hey James! How odd :/ Please call our Contact Centre on 02392441234 and we will be able to assist you :) Many thanks!',
#  '@DespiteOfficial we had a listen last night :) As You Bleed is an amazing track. When are you in Scotland?!',
#  '@97sides CONGRATS :)',
#  'yeaaaah yippppy!!!  my accnt verified rqst has succeed got a blue tick mark on my fb profile :) in 15 days',
#  '@BhaktisBanter @PallaviRuhail This one is irresistible :)\n#FlipkartFashionFriday http://t.co/EbZ0L2VENM',
#  "We don't like to keep our lovely customers waiting for long! We hope you enjoy! Happy Friday! - LWWF :) https://t.co/smyYriipxI",
#  '@Impatientraider On second thought, there’s just not enough time for a DD :) But new shorts entering system. Sheep must be buying.',
#  'Jgh , but we have to go to Bayan :D bye',
#  'As an act of mischievousness, am calling the ETL layer of our in-house warehousing app Katamari.\n\nWell… as the name implies :p.']

# %%
train_negative[0:10]
# Out:
# ['hopeless for tmr :(',
#  "Everything in the kids section of IKEA is so cute. Shame I'm nearly 19 in 2 months :(",
#  '@Hegelbon That heart sliding into the waste basket. :(',
#  '“@ketchBurning: I hate Japanese call him "bani" :( :(”\n\nMe too',
#  'Dang starting next week I have "work" :(',
#  "oh god, my babies' faces :( https://t.co/9fcwGvaki0",
#  '@RileyMcDonough make me smile :((',
#  '@f0ggstar @stuartthull work neighbour on motors. Asked why and he said hates the updates on search :( http://t.co/XvmTUikWln',
#  'why?:("@tahuodyy: sialan:( https://t.co/Hv1i0xcrL2"',
#  'Athabasca glacier was there in #1948 :-( #athabasca #glacier #jasper #jaspernationalpark #alberta #explorealberta #… http://t.co/dZZdqmf7Cz']

# %%
def clean_tweet(tweet):
    stemmer = PorterStemmer()
    stopwords_english = stopwords.words('english')
    
    tweet = re.sub(r'\$\w*','',tweet)
    # remove retweet text "RT"
    tweet = re.sub(r'RT[\s]+','',tweet)
    # remove hyperlinks
    tweet = re.sub(r'https?:\/\/.*[\r\n]*','',tweet)
    #remove # sign
    tweet = re.sub(r'#','',tweet)
    #tokenizing the tweets
    tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True,
                               reduce_len=True)
    tweet_tokens = tokenizer.tokenize(tweet)
    
    cleaned_tweet=[]
    for word in tweet_tokens:
        if(word not in stopwords_english and word not in string.punctuation):
            stem_word = stemmer.stem(word)
            cleaned_tweet.append(stem_word)
    return cleaned_tweet

# %%
clean_tweet(train_negative[0])
# Out:
# ['hopeless', 'tmr', ':(']

# %%
def count_tweets(result, tweets, sentiment):
    #result= preexisting dictionary
    #tweets = group of tweets
    #sentiment = group of tags of the tweets supplies
    for tag,tweet in zip(sentiment,tweets):
        cleaned_tweet = clean_tweet(tweet)
        for word in cleaned_tweet:
            pair = (word,tag)
            
            result[pair] = result.get(pair,0) + 1
            
#             if pair in result:
#                 result[pair] += 1
#             else:
#                 result[pair] += 1
    return result

# %%
result = {}
tweets = ['i am happy', 'i am tricked', 'i am sad', 'i am tired', 'i am tired']
ys = [1, 0, 0, 0, 0]
count_tweets(result, tweets, ys)
# Out:
# {('happi', 1): 1, ('trick', 0): 1, ('sad', 0): 1, ('tire', 0): 2}

# %%
#getting the frequencies of all the words
freqs = count_tweets({},train_x,train_y)

# %%
freqs
# Out:
# {('followfriday', 1.0): 23,
#  ('top', 1.0): 30,
#  ('engag', 1.0): 7,
#  ('member', 1.0): 14,
#  ('commun', 1.0): 27,
#  ('week', 1.0): 72,
#  (':)', 1.0): 2847,
#  ('hey', 1.0): 60,
#  ('jame', 1.0): 7,
#  ('odd', 1.0): 2,
#  (':/', 1.0): 5,
#  ('pleas', 1.0): 80,
#  ('call', 1.0): 27,
#  ('contact', 1.0): 4,
#  ('centr', 1.0): 1,
#  ('02392441234', 1.0): 1,
#  ('abl', 1.0): 6,
#  ('assist', 1.0): 1,
#  ('mani', 1.0): 28,
#  ('thank', 1.0): 504,
#  ('listen', 1.0): 14,
#  ('last', 1.0): 39,
#  ('night', 1.0): 55,
#  ('bleed', 1.0): 2,
#  ('amaz', 1.0): 41,
#  ('track', 1.0): 5,
#  ('scotland', 1.0): 2,
#  ('congrat', 1.0): 15,
#  ('yeaaah', 1.0): 1,
#  ('yipppi', 1.0): 1,
#  ('accnt', 1.0): 2,
#  ('verifi', 1.0): 2,
#  ('rqst', 1.0): 1,
#  ('succeed', 1.0): 1,
#  ('got', 1.0): 57,
#  ('blue', 1.0): 8,
#  ('tick', 1.0): 1,
#  ('mark', 1.0): 1,
#  ('fb', 1.0): 4,
#  ('profil', 1.0): 2,
#  ('15', 1.0): 4,
#  ('day', 1.0): 187,
#  ('one', 1.0): 90,
#  ('irresist', 1.0): 2,
#  ('flipkartfashionfriday', 1.0): 16,
#  ('like', 1.0): 187,
#  ('keep', 1.0): 55,
#  ('love', 1.0): 335,
#  ('custom', 1.0): 4,
#  ('wait', 1.0): 55,
#  ('long', 1.0): 27,
#  ('hope', 1.0): 113,
#  ('enjoy', 1.0): 57,
#  ('happi', 1.0): 161,
#  ('friday', 1.0): 91,
#  ('lwwf', 1.0): 1,
#  ('second', 1.0): 8,
#  ('thought', 1.0): 21,
#  ('’', 1.0): 17,
#  ('enough', 1.0): 16,
#  ('time', 1.0): 100,
#  ('dd', 1.0): 1,
#  ('new', 1.0): 111,
#  ('short', 1.0): 6,
#  ('enter', 1.0): 9,
#  ('system', 1.0): 2,
#  ('sheep', 1.0): 1,
#  ('must', 1.0): 14,
#  ('buy', 1.0): 9,
#  ('jgh', 1.0): 4,
#  ('go', 1.0): 120,
#  ('bayan', 1.0): 1,
#  (':D', 1.0): 498,
#  ('bye', 1.0): 5,
#  ('act', 1.0): 6,
#  ('mischiev', 1.0): 1,
#  ('etl', 1.0): 1,
#  ('layer', 1.0): 1,
#  ('in-hous', 1.0): 1,
#  ('wareh', 1.0): 1,
#  ('app', 1.0): 12,
#  ('katamari', 1.0): 1,
#  ('well', 1.0): 66,
#  ('…', 1.0): 31,
#  ('name', 1.0): 12,
#  ('impli', 1.0): 1,
#  (':p', 1.0): 103,
#  ('influenc', 1.0): 16,
#  ('big', 1.0): 27,
#  ('...', 1.0): 227,
#  ('juici', 1.0): 3,
#  ('selfi', 1.0): 11,
#  ('follow', 1.0): 319,
#  ('perfect', 1.0): 17,
#  ('alreadi', 1.0): 19,
#  ('know', 1.0): 120,
#  ("what'", 1.0): 14,
#  ('great', 1.0): 134,
#  ('opportun', 1.0): 17,
#  ('junior', 1.0): 2,
#  ('triathlet', 1.0): 1,
#  ('age', 1.0): 2,
#  ('12', 1.0): 5,
#  ('13', 1.0): 5,
#  ('gatorad', 1.0): 1,
#  ('seri', 1.0): 4,
#  ('get', 1.0): 164,
#  ('entri', 1.0): 3,
#  ('lay', 1.0): 3,
#  ('greet', 1.0): 4,
#  ('card', 1.0): 6,
#  ('rang', 1.0): 2,
#  ('print', 1.0): 3,
#  ('today', 1.0): 86,
#  ('job', 1.0): 34,
#  (':-)', 1.0): 543,
#  ("friend'", 1.0): 3,
#  ('lunch', 1.0): 3,
#  ('yummm', 1.0): 1,
#  ('nostalgia', 1.0): 1,
#  ('tb', 1.0): 1,
#  ('ku', 1.0): 1,
#  ('id', 1.0): 8,
#  ('conflict', 1.0): 1,
#  ('help', 1.0): 37,
#  ("here'", 1.0): 20,
#  ('screenshot', 1.0): 2,
#  ('work', 1.0): 88,
#  ('hi', 1.0): 154,
#  ('liv', 1.0): 2,
#  ('hello', 1.0): 49,
#  ('need', 1.0): 62,
#  ('someth', 1.0): 25,
#  ('u', 1.0): 136,
#  ('fm', 1.0): 2,
#  ('twitter', 1.0): 25,
#  ('—', 1.0): 22,
#  ('sure', 1.0): 37,
#  ('thing', 1.0): 48,
#  ('dm', 1.0): 34,
#  ('x', 1.0): 50,
#  ("i'v", 1.0): 25,
#  ('heard', 1.0): 9,
#  ('four', 1.0): 5,
#  ('season', 1.0): 5,
#  ('pretti', 1.0): 17,
#  ('dope', 1.0): 2,
#  ('penthous', 1.0): 1,
#  ('obv', 1.0): 1,
#  ('gobigorgohom', 1.0): 1,
#  ('fun', 1.0): 45,
#  ("y'all", 1.0): 3,
#  ('yeah', 1.0): 30,
#  ('suppos', 1.0): 6,
#  ('lol', 1.0): 48,
#  ('chat', 1.0): 9,
#  ('bit', 1.0): 16,
#  ('youth', 1.0): 14,
#  ('💅', 1.0): 1,
#  ('🏽', 1.0): 1,
#  ('💋', 1.0): 2,
#  ('seen', 1.0): 6,
#  ('year', 1.0): 33,
#  ('rest', 1.0): 9,
#  ('goe', 1.0): 4,
#  ('quickli', 1.0): 3,
#  ('bed', 1.0): 8,
#  ('music', 1.0): 15,
#  ('fix', 1.0): 6,
#  ('dream', 1.0): 17,
#  ('spiritu', 1.0): 1,
#  ('ritual', 1.0): 1,
#  ('festiv', 1.0): 7,
#  ('népal', 1.0): 1,
#  ('begin', 1.0): 4,
#  ('line-up', 1.0): 4,
#  ('left', 1.0): 10,
#  ('see', 1.0): 156,
#  ('sarah', 1.0): 4,
#  ('send', 1.0): 17,
#  ('us', 1.0): 91,
#  ('email', 1.0): 22,
#  ('bitsy@bitdefender.com', 1.0): 1,
#  ("we'll", 1.0): 12,
#  ('asap', 1.0): 5,
#  ('kik', 1.0): 16,
#  ('hatessuc', 1.0): 1,
#  ('32429', 1.0): 1,
#  ('kikm', 1.0): 1,
#  ('lgbt', 1.0): 2,
#  ('tinder', 1.0): 1,
#  ('nsfw', 1.0): 1,
#  ('akua', 1.0): 1,
#  ('cumshot', 1.0): 1,
#  ('come', 1.0): 63,
#  ('hous', 1.0): 5,
#  ('nsn_supplement', 1.0): 1,
#  ('effect', 1.0): 2,
#  ('press', 1.0): 1,
#  ('releas', 1.0): 11,
#  ('distribut', 1.0): 1,
#  ('result', 1.0): 2,
#  ('link', 1.0): 13,
#  ('remov', 1.0): 3,
#  ('pressreleas', 1.0): 1,
#  ('newsdistribut', 1.0): 1,
#  ('bam', 1.0): 44,
#  ('bestfriend', 1.0): 50,
#  ('lot', 1.0): 80,
#  ('warsaw', 1.0): 44,
#  ('<3', 1.0): 118,
#  ('x46', 1.0): 1,
#  ('everyon', 1.0): 45,
#  ('watch', 1.0): 32,
#  ('documentari', 1.0): 1,
#  ('earthl', 1.0): 1,
#  ('youtub', 1.0): 8,
#  ('support', 1.0): 25,
#  ('buuut', 1.0): 1,
#  ('oh', 1.0): 44,
#  ('look', 1.0): 109,
#  ('forward', 1.0): 20,
#  ('visit', 1.0): 25,
#  ('next', 1.0): 37,
#  ('letsgetmessi', 1.0): 1,
#  ('jo', 1.0): 1,
#  ('make', 1.0): 69,
#  ('feel', 1.0): 33,
#  ('better', 1.0): 40,
#  ('never', 1.0): 31,
#  ('anyon', 1.0): 7,
#  ('kpop', 1.0): 1,
#  ('flesh', 1.0): 1,
#  ('good', 1.0): 191,
#  ('girl', 1.0): 34,
#  ('best', 1.0): 49,
#  ('wish', 1.0): 29,
#  ('reason', 1.0): 10,
#  ('epic', 1.0): 1,
#  ('soundtrack', 1.0): 1,
#  ('shout', 1.0): 11,
#  ('ad', 1.0): 10,
#  ('video', 1.0): 29,
#  ('playlist', 1.0): 5,
#  ('would', 1.0): 70,
#  ('dear', 1.0): 15,
#  ('jordan', 1.0): 1,
#  ('okay', 1.0): 31,
#  ('fake', 1.0): 1,
#  ('gameplay', 1.0): 1,
#  (';)', 1.0): 22,
#  ('haha', 1.0): 44,
#  ('im', 1.0): 38,
#  ('kid', 1.0): 13,
#  ('stuff', 1.0): 11,
#  ('exactli', 1.0): 5,
#  ('product', 1.0): 11,
#  ('line', 1.0): 6,
#  ('etsi', 1.0): 1,
#  ('shop', 1.0): 12,
#  ('check', 1.0): 38,
#  ('vacat', 1.0): 5,
#  ('recharg', 1.0): 1,
#  ('normal', 1.0): 5,
#  ('charger', 1.0): 2,
#  ('asleep', 1.0): 7,
#  ('talk', 1.0): 37,
#  ('sooo', 1.0): 6,
#  ('someon', 1.0): 29,
#  ('text', 1.0): 12,
#  ('ye', 1.0): 60,
#  ('bet', 1.0): 6,
#  ("he'll", 1.0): 2,
#  ('fit', 1.0): 2,
#  ('hear', 1.0): 24,
#  ('speech', 1.0): 1,
#  ('piti', 1.0): 2,
#  ('green', 1.0): 2,
#  ('garden', 1.0): 5,
#  ('midnight', 1.0): 1,
#  ('sun', 1.0): 6,
#  ('beauti', 1.0): 45,
#  ('canal', 1.0): 1,
#  ('dasvidaniya', 1.0): 1,
#  ('till', 1.0): 16,
#  ('scout', 1.0): 1,
#  ('sg', 1.0): 1,
#  ('futur', 1.0): 9,
#  ('wlan', 1.0): 1,
#  ('pro', 1.0): 4,
#  ('confer', 1.0): 1,
#  ('asia', 1.0): 1,
#  ('chang', 1.0): 20,
#  ('lollipop', 1.0): 1,
#  ('🍭', 1.0): 1,
#  ('nez', 1.0): 1,
#  ('agnezmo', 1.0): 1,
#  ('oley', 1.0): 1,
#  ('mama', 1.0): 1,
#  ('stand', 1.0): 6,
#  ('stronger', 1.0): 1,
#  ('god', 1.0): 14,
#  ('misti', 1.0): 1,
#  ('babi', 1.0): 17,
#  ('cute', 1.0): 21,
#  ('woohoo', 1.0): 3,
#  ("can't", 1.0): 31,
#  ('sign', 1.0): 9,
#  ('yet', 1.0): 12,
#  ('still', 1.0): 37,
#  ('think', 1.0): 48,
#  ('mka', 1.0): 5,
#  ('liam', 1.0): 5,
#  ('access', 1.0): 3,
#  ('welcom', 1.0): 54,
#  ('stat', 1.0): 51,
#  ('arriv', 1.0): 57,
#  ('1', 1.0): 60,
#  ('unfollow', 1.0): 53,
#  ('via', 1.0): 60,
#  ('surpris', 1.0): 10,
#  ('figur', 1.0): 5,
#  ('happybirthdayemilybett', 1.0): 1,
#  ('sweet', 1.0): 16,
#  ('talent', 1.0): 4,
#  ('2', 1.0): 40,
#  ('plan', 1.0): 21,
#  ('drain', 1.0): 1,
#  ('gotta', 1.0): 4,
#  ('timezon', 1.0): 1,
#  ('parent', 1.0): 4,
#  ('proud', 1.0): 11,
#  ('least', 1.0): 14,
#  ('mayb', 1.0): 17,
#  ('sometim', 1.0): 11,
#  ('grade', 1.0): 4,
#  ('al', 1.0): 3,
#  ('grand', 1.0): 4,
#  ('manila_bro', 1.0): 1,
#  ('chosen', 1.0): 1,
#  ('let', 1.0): 57,
#  ('around', 1.0): 14,
#  ('..', 1.0): 100,
#  ('side', 1.0): 13,
#  ('world', 1.0): 23,
#  ('eh', 1.0): 2,
#  ('take', 1.0): 30,
#  ('care', 1.0): 12,
#  ('final', 1.0): 24,
#  ('fuck', 1.0): 20,
#  ('weekend', 1.0): 61,
#  ('real', 1.0): 18,
#  ('x45', 1.0): 1,
#  ('join', 1.0): 21,
#  ('hushedcallwithfraydo', 1.0): 1,
#  ('gift', 1.0): 7,
#  ('yeahhh', 1.0): 1,
#  ('hushedpinwithsammi', 1.0): 2,
#  ('event', 1.0): 7,
#  ('might', 1.0): 21,
#  ('luv', 1.0): 4,
#  ('realli', 1.0): 66,
#  ('appreci', 1.0): 28,
#  ('share', 1.0): 41,
#  ('wow', 1.0): 14,
#  ('tom', 1.0): 5,
#  ('gym', 1.0): 3,
#  ('monday', 1.0): 7,
#  ('invit', 1.0): 15,
#  ('scope', 1.0): 5,
#  ('friend', 1.0): 40,
#  ('nude', 1.0): 1,
#  ('sleep', 1.0): 35,
#  ('birthday', 1.0): 53,
#  ('want', 1.0): 69,
#  ('t-shirt', 1.0): 2,
#  ('cool', 1.0): 29,
#  ('haw', 1.0): 1,
#  ('phela', 1.0): 1,
#  ('mom', 1.0): 7,
#  ('obvious', 1.0): 1,
#  ('princ', 1.0): 1,
#  ('charm', 1.0): 1,
#  ('stage', 1.0): 2,
#  ('luck', 1.0): 26,
#  ('tyler', 1.0): 1,
#  ('hipster', 1.0): 1,
#  ('glass', 1.0): 3,
#  ('marti', 1.0): 2,
#  ('glad', 1.0): 41,
#  ('done', 1.0): 40,
#  ('afternoon', 1.0): 7,
#  ('read', 1.0): 27,
#  ('kahfi', 1.0): 1,
#  ('finish', 1.0): 15,
#  ('ohmyg', 1.0): 1,
#  ('yaya', 1.0): 3,
#  ('dub', 1.0): 1,
#  ('stalk', 1.0): 2,
#  ('ig', 1.0): 3,
#  ('gondooo', 1.0): 1,
#  ('moo', 1.0): 2,
#  ('tologooo', 1.0): 1,
#  ('becom', 1.0): 8,
#  ('detail', 1.0): 8,
#  ('zzz', 1.0): 1,
#  ('xx', 1.0): 33,
#  ('physiotherapi', 1.0): 1,
#  ('hashtag', 1.0): 3,
#  ('💪', 1.0): 1,
#  ('monica', 1.0): 1,
#  ('miss', 1.0): 17,
#  ('sound', 1.0): 20,
#  ('morn', 1.0): 68,
#  ("that'", 1.0): 49,
#  ('x43', 1.0): 1,
#  ('definit', 1.0): 20,
#  ('tri', 1.0): 34,
#  ('tonight', 1.0): 15,
#  ('took', 1.0): 7,
#  ('advic', 1.0): 6,
#  ('treviso', 1.0): 1,
#  ('concert', 1.0): 23,
#  ('citi', 1.0): 26,
#  ('countri', 1.0): 22,
#  ("i'll", 1.0): 73,
#  ('start', 1.0): 56,
#  ('fine', 1.0): 7,
#  ('gorgeou', 1.0): 9,
#  ('xo', 1.0): 2,
#  ('oven', 1.0): 2,
#  ('roast', 1.0): 1,
#  ('garlic', 1.0): 1,
#  ('oliv', 1.0): 1,
#  ('oil', 1.0): 4,
#  ('dri', 1.0): 4,
#  ('tomato', 1.0): 1,
#  ('basil', 1.0): 1,
#  ('centuri', 1.0): 1,
#  ('tuna', 1.0): 1,
#  ('right', 1.0): 38,
#  ('back', 1.0): 74,
#  ('atchya', 1.0): 1,
#  ('even', 1.0): 26,
#  ('almost', 1.0): 8,
#  ('chanc', 1.0): 3,
#  ('cheer', 1.0): 17,
#  ('po', 1.0): 3,
#  ('ice', 1.0): 6,
#  ('cream', 1.0): 6,
#  ('agre', 1.0): 13,
#  ('100', 1.0): 6,
#  ('heheheh', 1.0): 2,
#  ('that', 1.0): 10,
#  ('point', 1.0): 11,
#  ('stay', 1.0): 20,
#  ('home', 1.0): 20,
#  ('soon', 1.0): 38,
#  ('promis', 1.0): 4,
#  ('web', 1.0): 4,
#  ('whatsapp', 1.0): 3,
#  ('volta', 1.0): 1,
#  ('funcionar', 1.0): 1,
#  ('com', 1.0): 2,
#  ('iphon', 1.0): 7,
#  ('jailbroken', 1.0): 1,
#  ('later', 1.0): 11,
#  ('34', 1.0): 3,
#  ('min', 1.0): 7,
#  ('leia', 1.0): 1,
#  ('appear', 1.0): 3,
#  ('hologram', 1.0): 1,
#  ('r2d2', 1.0): 1,
#  ('w', 1.0): 16,
#  ('messag', 1.0): 9,
#  ('obi', 1.0): 1,
#  ('wan', 1.0): 1,
#  ('sit', 1.0): 7,
#  ('luke', 1.0): 4,
#  ('inter', 1.0): 1,
#  ('3', 1.0): 26,
#  ('ucl', 1.0): 1,
#  ('arsen', 1.0): 2,
#  ('small', 1.0): 1,
#  ('team', 1.0): 24,
#  ('pass', 1.0): 10,
#  ('🚂', 1.0): 1,
#  ('dewsburi', 1.0): 2,
#  ('railway', 1.0): 1,
#  ('station', 1.0): 4,
#  ('dew', 1.0): 1,
#  ('west', 1.0): 1,
#  ('yorkshir', 1.0): 2,
#  ('430', 1.0): 1,
#  ('smh', 1.0): 2,
#  ('9:25', 1.0): 1,
#  ('live', 1.0): 21,
#  ('strang', 1.0): 4,
#  ('imagin', 1.0): 5,
#  ('megan', 1.0): 1,
#  ('masaantoday', 1.0): 4,
#  ('a4', 1.0): 3,
#  ('shweta', 1.0): 1,
#  ('tripathi', 1.0): 1,
#  ('5', 1.0): 15,
#  ('20', 1.0): 5,
#  ('kurta', 1.0): 3,
#  ('half', 1.0): 6,
#  ('number', 1.0): 11,
#  ('wsalelov', 1.0): 14,
#  ('ah', 1.0): 12,
#  ('larri', 1.0): 3,
#  ('anyway', 1.0): 14,
#  ('kinda', 1.0): 12,
#  ('goood', 1.0): 1,
#  ('life', 1.0): 36,
#  ('enn', 1.0): 1,
#  ('could', 1.0): 25,
#  ('warmup', 1.0): 1,
#  ('15th', 1.0): 2,
#  ('bath', 1.0): 6,
#  ('dum', 1.0): 2,
#  ('andar', 1.0): 1,
#  ('ram', 1.0): 1,
#  ('sampath', 1.0): 1,
#  ('sona', 1.0): 1,
#  ('mohapatra', 1.0): 1,
#  ('samantha', 1.0): 1,
#  ('edward', 1.0): 1,
#  ('mein', 1.0): 1,
#  ('tulan', 1.0): 1,
#  ('razi', 1.0): 2,
#  ('wah', 1.0): 2,
#  ('josh', 1.0): 1,
#  ('alway', 1.0): 48,
#  ('smile', 1.0): 47,
#  ('pictur', 1.0): 7,
#  ('16.20', 1.0): 1,
#  ('giveitup', 1.0): 1,
#  ('given', 1.0): 3,
#  ('ga', 1.0): 3,
#  ('subsidi', 1.0): 1,
#  ('initi', 1.0): 2,
#  ('propos', 1.0): 3,
#  ('delight', 1.0): 4,
#  ('yesterday', 1.0): 4,
#  ('x42', 1.0): 1,
#  ('lmaoo', 1.0): 2,
#  ('song', 1.0): 16,
#  ('ever', 1.0): 19,
#  ('shall', 1.0): 5,
#  ('littl', 1.0): 29,
#  ('throwback', 1.0): 3,
#  ('outli', 1.0): 1,
#  ('island', 1.0): 2,
#  ('cheung', 1.0): 1,
#  ('chau', 1.0): 1,
#  ('mui', 1.0): 1,
#  ('wo', 1.0): 1,
#  ('total', 1.0): 5,
#  ('differ', 1.0): 10,
#  ('kfckitchentour', 1.0): 2,
#  ('kitchen', 1.0): 3,
#  ('clean', 1.0): 1,
#  ("i'm", 1.0): 140,
#  ('cusp', 1.0): 1,
#  ('test', 1.0): 7,
#  ('water', 1.0): 7,
#  ('reward', 1.0): 1,
#  ('arummzz', 1.0): 2,
#  ("let'", 1.0): 18,
#  ('drive', 1.0): 9,
#  ('travel', 1.0): 19,
#  ('yogyakarta', 1.0): 3,
#  ('jeep', 1.0): 3,
#  ('indonesia', 1.0): 3,
#  ('instamood', 1.0): 3,
#  ('wanna', 1.0): 23,
#  ('skype', 1.0): 3,
#  ('may', 1.0): 16,
#  ('nice', 1.0): 70,
#  ('friendli', 1.0): 1,
#  ('pretend', 1.0): 2,
#  ('film', 1.0): 8,
#  ('congratul', 1.0): 9,
#  ('winner', 1.0): 3,
#  ('cheesydelight', 1.0): 1,
#  ('contest', 1.0): 5,
#  ('address', 1.0): 8,
#  ('guy', 1.0): 48,
#  ('market', 1.0): 5,
#  ('24/7', 1.0): 1,
#  ('14', 1.0): 1,
#  ('hour', 1.0): 24,
#  ('leav', 1.0): 11,
#  ('without', 1.0): 9,
#  ('delay', 1.0): 1,
#  ('actual', 1.0): 13,
#  ('easi', 1.0): 7,
#  ('guess', 1.0): 8,
#  ('train', 1.0): 7,
#  ('wd', 1.0): 1,
#  ('shift', 1.0): 4,
#  ('engin', 1.0): 1,
#  ('etc', 1.0): 2,
#  ('sunburn', 1.0): 1,
#  ('peel', 1.0): 2,
#  ('blog', 1.0): 27,
#  ('huge', 1.0): 9,
#  ('warm', 1.0): 4,
#  ('☆', 1.0): 3,
#  ('complet', 1.0): 10,
#  ('triangl', 1.0): 2,
#  ('northern', 1.0): 1,
#  ('ireland', 1.0): 2,
#  ('sight', 1.0): 1,
#  ('smthng', 1.0): 2,
#  ('fr', 1.0): 3,
#  ('hug', 1.0): 11,
#  ('xoxo', 1.0): 3,
#  ('uu', 1.0): 1,
#  ('jaann', 1.0): 1,
#  ('topnewfollow', 1.0): 2,
#  ('connect', 1.0): 13,
#  ('wonder', 1.0): 26,
#  ('made', 1.0): 38,
#  ('fluffi', 1.0): 1,
#  ('insid', 1.0): 7,
#  ('pirouett', 1.0): 1,
#  ('moos', 1.0): 1,
#  ('trip', 1.0): 12,
#  ('philli', 1.0): 1,
#  ('decemb', 1.0): 2,
#  ("i'd", 1.0): 13,
#  ('dude', 1.0): 6,
#  ('x41', 1.0): 1,
#  ('question', 1.0): 15,
#  ('flaw', 1.0): 1,
#  ('pain', 1.0): 8,
#  ('negat', 1.0): 1,
#  ('strength', 1.0): 2,
#  ('went', 1.0): 10,
#  ('solo', 1.0): 4,
#  ('move', 1.0): 9,
#  ('fav', 1.0): 11,
#  ('nirvana', 1.0): 1,
#  ('smell', 1.0): 2,
#  ('teen', 1.0): 3,
#  ('spirit', 1.0): 1,
#  ('rip', 1.0): 3,
#  ('ami', 1.0): 4,
#  ('winehous', 1.0): 1,
#  ('coupl', 1.0): 5,
#  ('tomhiddleston', 1.0): 1,
#  ('elizabetholsen', 1.0): 1,
#  ('yaytheylookgreat', 1.0): 1,
#  ('goodnight', 1.0): 18,
#  ('vid', 1.0): 8,
#  ('wake', 1.0): 10,
#  ('gonna', 1.0): 16,
#  ('shoot', 1.0): 5,
#  ('itti', 1.0): 2,
#  ('bitti', 1.0): 2,
#  ('teeni', 1.0): 2,
#  ('bikini', 1.0): 3,
#  ('much', 1.0): 73,
#  ('4th', 1.0): 4,
#  ('togeth', 1.0): 6,
#  ('end', 1.0): 13,
#  ('xfile', 1.0): 1,
#  ('content', 1.0): 3,
#  ('rain', 1.0): 18,
#  ('fabul', 1.0): 4,
#  ('fantast', 1.0): 8,
#  ('♡', 1.0): 12,
#  ('jb', 1.0): 1,
#  ('forev', 1.0): 5,
#  ('belieb', 1.0): 3,
#  ('nighti', 1.0): 1,
#  ('bug', 1.0): 2,
#  ('bite', 1.0): 1,
#  ('bracelet', 1.0): 2,
#  ('idea', 1.0): 23,
#  ('foundri', 1.0): 1,
#  ('game', 1.0): 23,
#  ('sens', 1.0): 6,
#  ('pic', 1.0): 21,
#  ('ef', 1.0): 1,
#  ('phone', 1.0): 16,
#  ('woot', 1.0): 2,
#  ('derek', 1.0): 1,
#  ('use', 1.0): 32,
#  ('parkshar', 1.0): 1,
#  ('gloucestershir', 1.0): 1,
#  ('aaaahhh', 1.0): 1,
#  ('man', 1.0): 16,
#  ('traffic', 1.0): 2,
#  ('stress', 1.0): 4,
#  ('reliev', 1.0): 1,
#  ("how'r", 1.0): 1,
#  ('arbeloa', 1.0): 1,
#  ('turn', 1.0): 13,
#  ('17', 1.0): 2,
#  ('omg', 1.0): 13,
#  ('say', 1.0): 43,
#  ('europ', 1.0): 1,
#  ('rise', 1.0): 2,
#  ('find', 1.0): 20,
#  ('hard', 1.0): 9,
#  ('believ', 1.0): 7,
#  ('uncount', 1.0): 1,
#  ('coz', 1.0): 2,
#  ('unlimit', 1.0): 1,
#  ('cours', 1.0): 11,
#  ('teamposit', 1.0): 1,
#  ('aldub', 1.0): 2,
#  ('☕', 1.0): 3,
#  ('rita', 1.0): 2,
#  ('info', 1.0): 10,
#  ("we'd", 1.0): 4,
#  ('way', 1.0): 34,
#  ('boy', 1.0): 13,
#  ('x40', 1.0): 1,
#  ('true', 1.0): 19,
#  ('sethi', 1.0): 2,
#  ('high', 1.0): 6,
#  ('exe', 1.0): 1,
#  ('skeem', 1.0): 1,
#  ('saam', 1.0): 1,
#  ('peopl', 1.0): 42,
#  ('polit', 1.0): 2,
#  ('izzat', 1.0): 1,
#  ('wese', 1.0): 1,
#  ('trust', 1.0): 7,
#  ('khawateen', 1.0): 1,
#  ('k', 1.0): 8,
#  ('sath', 1.0): 2,
#  ('mana', 1.0): 1,
#  ('kar', 1.0): 1,
#  ('deya', 1.0): 1,
#  ('sort', 1.0): 7,
#  ('smart', 1.0): 5,
#  ('hair', 1.0): 7,
#  ('tbh', 1.0): 5,
#  ('jacob', 1.0): 2,
#  ('g', 1.0): 7,
#  ('upgrad', 1.0): 2,
#  ('tee', 1.0): 2,
#  ('famili', 1.0): 14,
#  ('person', 1.0): 14,
#  ('two', 1.0): 15,
#  ('convers', 1.0): 6,
#  ('onlin', 1.0): 4,
#  ('mclaren', 1.0): 1,
#  ('fridayfeel', 1.0): 5,
#  ('tgif', 1.0): 8,
#  ('squar', 1.0): 1,
#  ('enix', 1.0): 1,
#  ('bissmillah', 1.0): 1,
#  ('ya', 1.0): 19,
#  ('allah', 1.0): 3,
#  ("we'r", 1.0): 25,
#  ('socent', 1.0): 1,
#  ('startup', 1.0): 2,
#  ('drop', 1.0): 9,
#  ('your', 1.0): 3,
#  ('arnd', 1.0): 1,
#  ('town', 1.0): 3,
#  ('basic', 1.0): 4,
#  ('piss', 1.0): 2,
#  ('cup', 1.0): 4,
#  ('also', 1.0): 28,
#  ('terribl', 1.0): 2,
#  ('complic', 1.0): 1,
#  ('discuss', 1.0): 2,
#  ('snapchat', 1.0): 31,
#  ('lynettelow', 1.0): 1,
#  ('kikmenow', 1.0): 2,
#  ('snapm', 1.0): 1,
#  ('hot', 1.0): 20,
#  ('amazon', 1.0): 1,
#  ('kikmeguy', 1.0): 2,
#  ('defin', 1.0): 2,
#  ('grow', 1.0): 6,
#  ('sport', 1.0): 4,
#  ('rt', 1.0): 9,
#  ('rakyat', 1.0): 1,
#  ('write', 1.0): 11,
#  ('sinc', 1.0): 11,
#  ('mention', 1.0): 18,
#  ('fli', 1.0): 5,
#  ('fish', 1.0): 3,
#  ('promot', 1.0): 3,
#  ('post', 1.0): 16,
#  ('cyber', 1.0): 1,
#  ('ourdaughtersourprid', 1.0): 3,
#  ('mypapamyprid', 1.0): 2,
#  ('papa', 1.0): 1,
#  ('coach', 1.0): 2,
#  ('posit', 1.0): 3,
#  ('kha', 1.0): 1,
#  ('atleast', 1.0): 2,
#  ('x39', 1.0): 1,
#  ('mango', 1.0): 1,
#  ("lassi'", 1.0): 1,
#  ("monty'", 1.0): 1,
#  ('marvel', 1.0): 2,
#  ('though', 1.0): 16,
#  ('suspect', 1.0): 3,
#  ('meant', 1.0): 2,
#  ('24', 1.0): 3,
#  ('hr', 1.0): 2,
#  ('touch', 1.0): 7,
#  ('kepler', 1.0): 3,
#  ('452b', 1.0): 4,
#  ('chalna', 1.0): 1,
#  ('hai', 1.0): 7,
#  ('thankyou', 1.0): 12,
#  ('hazel', 1.0): 1,
#  ('food', 1.0): 6,
#  ('brooklyn', 1.0): 1,
#  ('pta', 1.0): 2,
#  ('awak', 1.0): 8,
#  ('okayi', 1.0): 2,
#  ('awww', 1.0): 12,
#  ('ha', 1.0): 18,
#  ('doc', 1.0): 1,
#  ('splendid', 1.0): 1,
#  ('spam', 1.0): 1,
#  ('folder', 1.0): 1,
#  ('amount', 1.0): 1,
#  ('nigeria', 1.0): 1,
#  ('claim', 1.0): 1,
#  ('rted', 1.0): 1,
#  ('leg', 1.0): 3,
#  ('hurt', 1.0): 4,
#  ('bad', 1.0): 14,
#  ('mine', 1.0): 11,
#  ('saturday', 1.0): 5,
#  ('thaaank', 1.0): 1,
#  ('puhon', 1.0): 1,
#  ('happinesss', 1.0): 1,
#  ('tnc', 1.0): 1,
#  ('prior', 1.0): 1,
#  ('notif', 1.0): 2,
#  ('fat', 1.0): 1,
#  ('co', 1.0): 1,
#  ('probabl', 1.0): 7,
#  ('ate', 1.0): 4,
#  ('yuna', 1.0): 2,
#  ('tamesid', 1.0): 1,
#  ('´', 1.0): 3,
#  ('googl', 1.0): 5,
#  ('account', 1.0): 17,
#  ('scouser', 1.0): 1,
#  ('everyth', 1.0): 10,
#  ('zoe', 1.0): 1,
#  ('mate', 1.0): 5,
#  ('liter', 1.0): 5,
#  ("they'r", 1.0): 10,
#  ('samee', 1.0): 1,
#  ('edgar', 1.0): 1,
#  ('updat', 1.0): 12,
#  ('log', 1.0): 3,
#  ('bring', 1.0): 12,
#  ('abe', 1.0): 1,
#  ('meet', 1.0): 26,
#  ('x38', 1.0): 1,
#  ('sigh', 1.0): 3,
#  ('dreamili', 1.0): 1,
#  ('pout', 1.0): 1,
#  ('eye', 1.0): 12,
#  ('quacketyquack', 1.0): 6,
#  ('funni', 1.0): 15,
#  ('happen', 1.0): 13,
#  ('phil', 1.0): 1,
#  ('em', 1.0): 2,
#  ('del', 1.0): 1,
#  ('rodder', 1.0): 1,
#  ('els', 1.0): 8,
#  ('play', 1.0): 37,
#  ('newest', 1.0): 1,
#  ('gamejam', 1.0): 1,
#  ('irish', 1.0): 2,
#  ('literatur', 1.0): 2,
#  ('inaccess', 1.0): 2,
#  ("kareena'", 1.0): 2,
#  ('fan', 1.0): 21,
#  ('brain', 1.0): 10,
#  ('dot', 1.0): 8,
#  ('braindot', 1.0): 8,
#  ('fair', 1.0): 4,
#  ('rush', 1.0): 1,
#  ('either', 1.0): 10,
#  ('brandi', 1.0): 1,
#  ('18', 1.0): 5,
#  ('carniv', 1.0): 1,
#  ('men', 1.0): 8,
#  ('put', 1.0): 11,
#  ('mask', 1.0): 2,
#  ('xavier', 1.0): 1,
#  ('forneret', 1.0): 1,
#  ('jennif', 1.0): 1,
#  ('site', 1.0): 7,
#  ('free', 1.0): 31,
#  ('50.000', 1.0): 3,
#  ('8', 1.0): 10,
#  ('ball', 1.0): 7,
#  ('pool', 1.0): 5,
#  ('coin', 1.0): 5,
#  ('edit', 1.0): 6,
#  ('trish', 1.0): 1,
#  ('♥', 1.0): 13,
#  ('grate', 1.0): 5,
#  ('three', 1.0): 8,
#  ('comment', 1.0): 7,
#  ('wakeup', 1.0): 1,
#  ('besid', 1.0): 2,
#  ('dirti', 1.0): 2,
#  ('sex', 1.0): 4,
#  ('lmaooo', 1.0): 1,
#  ('😤', 1.0): 2,
#  ('loui', 1.0): 4,
#  ("he'", 1.0): 10,
#  ('throw', 1.0): 3,
#  ('caus', 1.0): 11,
#  ('inspir', 1.0): 6,
#  ('ff', 1.0): 40,
#  ('twoof', 1.0): 3,
#  ('gr8', 1.0): 1,
#  ('wkend', 1.0): 3,
#  ('kind', 1.0): 22,
#  ('exhaust', 1.0): 2,
#  ('word', 1.0): 17,
#  ('cheltenham', 1.0): 1,
#  ('area', 1.0): 4,
#  ('kale', 1.0): 1,
#  ('crisp', 1.0): 1,
#  ('ruin', 1.0): 5,
#  ('x37', 1.0): 1,
#  ('open', 1.0): 12,
#  ('worldwid', 1.0): 2,
#  ('outta', 1.0): 1,
#  ('sfvbeta', 1.0): 1,
#  ('vantast', 1.0): 1,
#  ('xcylin', 1.0): 1,
#  ('bundl', 1.0): 1,
#  ('show', 1.0): 20,
#  ('internet', 1.0): 2,
#  ('price', 1.0): 3,
#  ('realisticli', 1.0): 1,
#  ('pay', 1.0): 8,
#  ('net', 1.0): 1,
#  ('educ', 1.0): 1,
#  ('power', 1.0): 6,
#  ('weapon', 1.0): 1,
#  ('nelson', 1.0): 1,
#  ('mandela', 1.0): 1,
#  ('recent', 1.0): 8,
#  ('j', 1.0): 2,
#  ('chenab', 1.0): 1,
#  ('flow', 1.0): 5,
#  ('pakistan', 1.0): 1,
#  ('incredibleindia', 1.0): 1,
#  ('teenchoic', 1.0): 7,
#  ('choiceinternationalartist', 1.0): 7,
#  ('superjunior', 1.0): 7,
#  ('caught', 1.0): 4,
#  ('first', 1.0): 41,
#  ('salmon', 1.0): 1,
#  ('super-blend', 1.0): 1,
#  ('project', 1.0): 6,
#  ('youth@bipolaruk.org.uk', 1.0): 1,
#  ('awesom', 1.0): 35,
#  ('stream', 1.0): 12,
#  ('alma', 1.0): 1,
#  ('mater', 1.0): 1,
#  ('highschoolday', 1.0): 1,
#  ('clientvisit', 1.0): 1,
#  ('faith', 1.0): 3,
#  ('christian', 1.0): 1,
#  ('school', 1.0): 9,
#  ('lizaminnelli', 1.0): 1,
#  ('upcom', 1.0): 2,
#  ('uk', 1.0): 4,
#  ('😄', 1.0): 3,
#  ('singl', 1.0): 4,
#  ('hill', 1.0): 4,
#  ('everi', 1.0): 23,
#  ('beat', 1.0): 7,
#  ('wrong', 1.0): 9,
#  ('readi', 1.0): 22,
#  ('natur', 1.0): 1,
#  ('pefumeri', 1.0): 1,
#  ('workshop', 1.0): 2,
#  ('neal', 1.0): 1,
#  ('yard', 1.0): 1,
#  ('covent', 1.0): 1,
#  ('tomorrow', 1.0): 31,
#  ('fback', 1.0): 26,
#  ...}

# %%
def train_naive_bayes(freqs, train_x, train_y):
    
    vocab = set([pair[0] for pair in freqs.keys()])
    V = len(vocab)
    loglikelihood = {}
    # count N_pos and N_neg
    N_pos = N_neg = 0
    for pair in freqs.keys():
        if pair[1]>0:
            N_pos += freqs[pair]
        else:
            N_neg += freqs[pair]
    
    D = len(train_y)
    D_pos = sum(train_y)
    D_neg = D - D_pos

    logprior = np.log(D_pos) - np.log(D_neg)

    for word in vocab:
        freq_pos = freqs.get((word,1.0),0)
        freq_neg = freqs.get((word,0.0),0)
        p_w_pos = (freq_pos)+1/(N_pos+V)
        p_w_neg = (freq_neg)+1/(N_neg+V)
        loglikelihood[word] = np.log(p_w_pos) - np.log(p_w_neg)
    return logprior, loglikelihood

# %%
logprior, loglikelihood = train_naive_bayes(freqs, train_x, train_y)

# %%
len(loglikelihood)
# Out:
# 9091

# %%
loglikelihood
# Out:
# {'photooftheday': 0.40546054257177644,
#  'm8': 10.494712888195956,
#  'lahhh': -10.489494712712904,
#  'wait': 0.42381398376298174,
#  'beginn': 10.494712888195956,
#  'lafayett': -11.182628051963462,
#  'mainli': 10.494712888195956,
#  'nwb': 10.494712888195956,
#  'donetsk': 10.494712888195956,
#  "else'": 0.6931334116641951,
#  'yahoo': -11.182628051963462,
#  '>:-(': -11.588088546259256,
#  'méxico': 1.4482526596205106e-07,
#  'adio': -10.489494712712904,
#  'flapjack': -10.489494712712904,
#  'jenna': 10.494712888195956,
#  'alot': -0.40546042188215625,
#  'headack': -10.489494712712904,
#  'font': 10.494712888195956,
#  '423': -10.489494712712904,
#  'abscess': -10.489494712712904,
#  'eventu': 1.4482526596205106e-07,
#  'wh': -10.489494712712904,
#  '1/2': -1.0985936887210854,
#  'momma': 0.6931334116641951,
#  '8p': -10.489494712712904,
#  'shitfac': 10.494712888195956,
#  '5word': 11.187846155034885,
#  'law': -0.6931401874197693,
#  'niqqa': -10.489494712712904,
#  'moistur': 10.494712888195956,
#  '2/4': -10.489494712712904,
#  'xiu': -10.489494712712904,
#  'caus': 0.09530994130585979,
#  'astonvilla': -10.489494712712904,
#  'rakna': 10.494712888195956,
#  'strap': -10.489494712712904,
#  'bye': -0.18232060505982361,
#  'blacklivesmatt': -10.489494712712904,
#  'deactiv': -12.098910478960024,
#  'shet': 10.494712888195956,
#  'supercar': -10.489494712712904,
#  'altern': 11.593306625193023,
#  '13': 0.9162824559622585,
#  'yaa': 11.593306625193023,
#  'elgin': -10.489494712712904,
#  'omegl': -0.6931401874197693,
#  'massi': -10.489494712712904,
#  'hyungwon': -10.489494712712904,
#  'promis': 0.28767980174468355,
#  'brush': 10.494712888195956,
#  'soooner': -10.489494712712904,
#  'smh': -0.6931401874197693,
#  'idk': -13.322682002380583,
#  '350': -10.489494712712904,
#  'bright': -0.6931331944252911,
#  'tone': -10.489494712712904,
#  'skrillah': -10.489494712712904,
#  'septum': -10.489494712712904,
#  "lassi'": 10.494712888195956,
#  'wear': -0.287679717261631,
#  '29th': 10.494712888195956,
#  'sneak': -0.40546042188215625,
#  'max': -0.6931331944252911,
#  'telat': 1.4482526596205106e-07,
#  'nudg': 10.494712888195956,
#  'ngeze': -10.489494712712904,
#  'du': -10.489494712712904,
#  'chum': -10.489494712712904,
#  'jcreport': 10.494712888195956,
#  'throwback': 11.593306625193023,
#  'frnd': 10.494712888195956,
#  'paralysi': 10.494712888195956,
#  'vex': 10.494712888195956,
#  'beme': 10.494712888195956,
#  'newer': -10.489494712712904,
#  'particularli': 11.187846155034885,
#  'snsd': -11.182628051963462,
#  'thorin': 10.494712888195956,
#  'fucjikg': -10.489494712712904,
#  'sarah': 11.880986378661724,
#  'richard': -11.182628051963462,
#  'mjhe': -11.182628051963462,
#  'georgia': -11.182628051963462,
#  'fic': 11.187846155034885,
#  'sweatpant': 10.494712888195956,
#  'retard': 10.494712888195956,
#  'destin': -10.489494712712904,
#  'cori': -10.489494712712904,
#  'john': 12.28644916778143,
#  'kikmenow': -0.916282354582924,
#  'hearess': -10.489494712712904,
#  'system': -0.40546042188215625,
#  'boner': -10.489494712712904,
#  'georgi': 1.4482526596205106e-07,
#  'diner': -10.489494712712904,
#  'lovey': -10.489494712712904,
#  'cnt': -10.489494712712904,
#  'thrice': 10.494712888195956,
#  'ilhoon': -10.489494712712904,
#  'strongest': 10.494712888195956,
#  'dartmoor': 10.494712888195956,
#  'cusp': 10.494712888195956,
#  'toni': 0.6931334116641951,
#  'subtitl': -10.489494712712904,
#  'serv': 1.4482526596205106e-07,
#  'purti': -10.489494712712904,
#  '>:(': -14.250667789391098,
#  'pant': -0.6931331944252911,
#  'roux': 10.494712888195956,
#  'babe': -0.8266763279586375,
#  '╭': 11.880986378661724,
#  'discount': -10.489494712712904,
#  'lorna': 10.494712888195956,
#  'neat-o': -10.489494712712904,
#  'hangout': -11.182628051963462,
#  'lyf': -10.489494712712904,
#  "it'd": 1.4482526596205106e-07,
#  'japan': -11.182628051963462,
#  'cag': -10.489494712712904,
#  'sembuh': 10.494712888195956,
#  'ditch': 10.494712888195956,
#  'xst': 10.494712888195956,
#  'd1': -10.489494712712904,
#  'luxurytravel': 10.494712888195956,
#  '10,000': 10.494712888195956,
#  'churro': -10.489494712712904,
#  'bitsy@bitdefender.com': 10.494712888195956,
#  'srijith': 10.494712888195956,
#  'bias': -10.489494712712904,
#  'stiffen': 10.494712888195956,
#  'matern': -10.489494712712904,
#  'nga': -10.489494712712904,
#  'case': -0.18232060505982361,
#  '877': -10.489494712712904,
#  'haileyhelp': 10.494712888195956,
#  'kathryn': 10.494712888195956,
#  'rumpi': -10.489494712712904,
#  'wetherspoon': -10.489494712712904,
#  'naw': -11.588088546259256,
#  'notch': -10.489494712712904,
#  'per': 10.494712888195956,
#  'germani': -11.588088546259256,
#  'dipikirin': 10.494712888195956,
#  'bunso': -10.489494712712904,
#  'man.h': 10.494712888195956,
#  'fam': 0.40546054257177644,
#  'askfinnick': -10.489494712712904,
#  'oval': 10.494712888195956,
#  'jest': -10.489494712712904,
#  'awww': -0.45953146738835216,
#  'healthylifestyl': 10.494712888195956,
#  'cooler': -10.489494712712904,
#  'minecraft': 12.440599185039572,
#  'futur': 0.8109263874396495,
#  'brag': -10.489494712712904,
#  'boii': 10.494712888195956,
#  'persuad': -10.489494712712904,
#  'minc': -10.489494712712904,
#  'cricket': -0.6931331944252911,
#  'wiv': -10.489494712712904,
#  'second': 0.9808235038199262,
#  'stoke': 10.494712888195956,
#  'bo': 10.494712888195956,
#  'hidden': 10.494712888195956,
#  'x34': 10.494712888195956,
#  'shogi': -10.489494712712904,
#  'rhi': 10.494712888195956,
#  'denmark': 1.4482526596205106e-07,
#  'cont': -11.182628051963462,
#  'pronounc': 10.494712888195956,
#  'cousin': 4.8275982100776105e-08,
#  "friend'": 11.593306625193023,
#  'lie': -0.916282354582924,
#  'gyllenha': -10.489494712712904,
#  'nba': 11.593306625193023,
#  '“': -0.6931451825050274,
#  'vinni': 10.494712888195956,
#  'dazzl': 10.494712888195956,
#  'sotw': 10.494712888195956,
#  'leas': -10.489494712712904,
#  'bristol': -10.489494712712904,
#  'shawn': -10.489494712712904,
#  'ming': -10.489494712712904,
#  '345': -10.489494712712904,
#  'camara': -10.489494712712904,
#  'reh': 10.494712888195956,
#  'newli': 10.494712888195956,
#  'scienc': 1.6094157952128156,
#  'univers': 11.187846155034885,
#  'tinder': -0.6931331944252911,
#  '<3': 1.826244424120774,
#  "microsoft'": -10.489494712712904,
#  'train': -0.35667373683032455,
#  'pabeb': -11.182628051963462,
#  'challo': -10.489494712712904,
#  'sinuend': -10.489494712712904,
#  'belat': 1.0985938818223335,
#  '50europ': 10.494712888195956,
#  'bayan': 10.494712888195956,
#  'preorder': 10.494712888195956,
#  'hol': -10.489494712712904,
#  'there': -0.6931401874197693,
#  'rod': 10.494712888195956,
#  'list': 1.2039663594357437,
#  'suckmejimin': -10.489494712712904,
#  "melody'": -10.489494712712904,
#  'abbi': 1.4482526596205106e-07,
#  'twoof': 11.593306625193023,
#  '12th': 1.4482526596205106e-07,
#  'abi': -10.489494712712904,
#  'alreadi': -0.7691322981057747,
#  '-->': 11.187846155034885,
#  'editor': -10.489494712712904,
#  'rize': -10.489494712712904,
#  'invoic': 10.494712888195956,
#  'genuin': -11.182628051963462,
#  'film': 1.3862839981157205,
#  'factori': -10.489494712712904,
#  'ridicul': -11.588088546259256,
#  'bummer': -11.182628051963462,
#  'yung': 1.4482526596205106e-07,
#  'letsfootbal': -10.489494712712904,
#  'chicsirif': -10.489494712712904,
#  'cuti': 1.6094157952128156,
#  'vomit': -10.489494712712904,
#  'hiya': 1.0985938818223335,
#  'store': 1.3862874524305009,
#  'yayayayay': 10.494712888195956,
#  'agn': 10.494712888195956,
#  '48': 10.494712888195956,
#  'bigot': 10.494712888195956,
#  'snobbi': 10.494712888195956,
#  'contradict': 10.494712888195956,
#  'notanapolog': 0.40546054257177644,
#  'speed': -11.182628051963462,
#  'inni': 11.187846155034885,
#  'jaspernationalpark': -10.489494712712904,
#  'coldest': -10.489494712712904,
#  'shiatsu': -10.489494712712904,
#  'awel': -10.489494712712904,
#  'opix': -10.489494712712904,
#  'aaahh': -10.489494712712904,
#  'nemesi': -10.489494712712904,
#  'whole': -0.6931443832863908,
#  'reliev': 10.494712888195956,
#  'switch': -1.0985936887210854,
#  'evil': 1.4482526596205106e-07,
#  'riptito': -10.489494712712904,
#  'son': 11.880986378661724,
#  'courgett': 10.494712888195956,
#  'portug': 10.494712888195956,
#  'impact': -10.489494712712904,
#  'lyin': -10.489494712712904,
#  ':-d': 12.104128538583506,
#  'tak': -0.6931331944252911,
#  'news': -0.11778283436048342,
#  'older': -12.098910478960024,
#  'semi': 10.494712888195956,
#  'yvett': 10.494712888195956,
#  'oshieer': 10.494712888195956,
#  'consumer': 10.494712888195956,
#  'kyli': -11.182628051963462,
#  'huhuu': -10.489494712712904,
#  'thr': -10.489494712712904,
#  'seehiah': -10.489494712712904,
#  'overdrawn': -10.489494712712904,
#  'gold': 1.945886441668882,
#  'els': 0.6931437382823131,
#  'pefumeri': 10.494712888195956,
#  'ironi': -10.489494712712904,
#  'pervert': 10.494712888195956,
#  'ramo': -10.489494712712904,
#  'majhwar': -10.489494712712904,
#  '342': -10.489494712712904,
#  'gyu': -11.875768311796868,
#  'talant': 10.494712888195956,
#  'wiw': 10.494712888195956,
#  'thirstyyi': -10.489494712712904,
#  '874': -10.489494712712904,
#  'quicker': 10.494712888195956,
#  'hungri': -1.8717903924611392,
#  'dresscod': -10.489494712712904,
#  'menac': 10.494712888195956,
#  'himach': 10.494712888195956,
#  'tri': -0.5340821447556601,
#  'ryu': 10.494712888195956,
#  'cilic': 11.593306625193023,
#  'compliment': 10.494712888195956,
#  '@the': -10.489494712712904,
#  'cakehamp': 10.494712888195956,
#  'find': -0.8109294399980449,
#  'mous': 11.187846155034885,
#  'drama': 10.494712888195956,
#  'pre-holiday': -10.489494712712904,
#  'wirh': 10.494712888195956,
#  'side': 0.7731874149933857,
#  'humid': 10.494712888195956,
#  'rogerwatch': -10.489494712712904,
#  'occur': -10.489494712712904,
#  'b-but': -10.489494712712904,
#  'settl': 10.494712888195956,
#  'uuu': 1.4482526596205106e-07,
#  'full': 0.4353171915482337,
#  'usag': -10.489494712712904,
#  'nigeria': 10.494712888195956,
#  'simpli': 11.593306625193023,
#  'bigger': -0.6931331944252911,
#  'countri': 1.4816002692101642,
#  '😵': -10.489494712712904,
#  'asia': 1.4482526596205106e-07,
#  'debt': 11.187846155034885,
#  'pta': 11.187846155034885,
#  '00962778381': 10.494712888195956,
#  'leav': -1.0360902948755637,
#  'wine': 1.0985938818223335,
#  'doushit': -10.489494712712904,
#  'iso': 10.494712888195956,
#  'better': 0.25489205232327405,
#  'hibb': -10.489494712712904,
#  'need': -0.32721278426698674,
#  'heard': 0.5877842202764949,
#  'repackag': -10.489494712712904,
#  'ramd': -10.489494712712904,
#  'nikki': 11.187846155034885,
#  'walkin': 10.494712888195956,
#  'mi': 0.6931402960404779,
#  'forget': 1.1631470124322152,
#  'kharap': -10.489494712712904,
#  'hotspotwithdanri': -10.489494712712904,
#  'l': 1.4482526596205106e-07,
#  'adu': -10.489494712712904,
#  'darn': -10.489494712712904,
#  'peanut': -11.588088546259256,
#  'resourc': -10.489494712712904,
#  'often': 0.6931334116641951,
#  'undercoverboss': -10.489494712712904,
#  'oth': 10.494712888195956,
#  'wew': -10.489494712712904,
#  'calum': 1.0985938818223335,
#  '325.000': 10.494712888195956,
#  'nirvana': 10.494712888195956,
#  'mingm': -10.489494712712904,
#  'stalk': -0.40546042188215625,
#  'indonesian': 10.494712888195956,
#  'nje': -10.489494712712904,
#  'kikgirl': -1.0986076386167383,
#  'choker': 10.494712888195956,
#  'cardio': 10.494712888195956,
#  'cheltenham': 10.494712888195956,
#  'crackl': 1.4482526596205106e-07,
#  'freed': -10.489494712712904,
#  'kgola': -10.489494712712904,
#  'duh': 11.187846155034885,
#  'delet': -12.098910478960024,
#  'somehow': -11.182628051963462,
#  'america': 1.4482526596205106e-07,
#  'renam': 10.494712888195956,
#  'puddl': -11.182628051963462,
#  'refurbish': -10.489494712712904,
#  'ta': 1.4482526596205106e-07,
#  'hbd': 1.4482526596205106e-07,
#  'yayyy': 1.4482526596205106e-07,
#  'stooop': -10.489494712712904,
#  '2nd': 2.896569650800984e-08,
#  'umaru': 10.494712888195956,
#  'lace': -10.489494712712904,
#  'amaz': 1.2286637887182073,
#  'hub': -10.489494712712904,
#  'lion': -1.0985936887210854,
#  'scale': -10.489494712712904,
#  'visual': 11.187846155034885,
#  'belli': -10.489494712712904,
#  'owl': 10.494712888195956,
#  'address': 0.9808235038199262,
#  'wayn': -11.182628051963462,
#  'halaaang': -10.489494712712904,
#  'twitch': 11.880986378661724,
#  'kidney': -11.182628051963462,
#  'cough': 1.098603085160185,
#  'expens': -12.43538113369197,
#  'tropic': 10.494712888195956,
#  'stationeri': 10.494712888195956,
#  'barnstapl': 10.494712888195956,
#  'asf': -10.489494712712904,
#  'tagal': -10.489494712712904,
#  'creak': 10.494712888195956,
#  'peru': 10.494712888195956,
#  'landscap': 11.187846155034885,
#  'conven': -10.489494712712904,
#  'tdc': -10.489494712712904,
#  'separ': 10.494712888195956,
#  '333': -10.489494712712904,
#  'zayyyn': -10.489494712712904,
#  'gari': 10.494712888195956,
#  '5am': -1.0985936887210854,
#  'alhamdullilah': 10.494712888195956,
#  'harap': -10.489494712712904,
#  'jp': -10.489494712712904,
#  'diffici': -10.489494712712904,
#  'wail': -10.489494712712904,
#  '333505': 10.494712888195956,
#  'plu': -0.287679717261631,
#  'israel': -10.489494712712904,
#  'forev': -0.3364706257662502,
#  '80x': 10.494712888195956,
#  'thwart': -10.489494712712904,
#  'fcking': -10.489494712712904,
#  'favour': 10.494712888195956,
#  'readi': 0.8938160650257627,
#  'meh': -11.588088546259256,
#  'busi': -0.33647169966785473,
#  'tose': 10.494712888195956,
#  'soamaz': 10.494712888195956,
#  'disabl': -11.182628051963462,
#  'xbox': 7.241363808585533e-08,
#  'tweenie_fox': 10.494712888195956,
#  'freez': -11.182628051963462,
#  'stafford': -10.489494712712904,
#  'sulk': -10.489494712712904,
#  'latin': 12.104128538583506,
#  'strike': 1.4482526596205106e-07,
#  'contestkiduniya': 11.187846155034885,
#  'uncut': 10.494712888195956,
#  'frail': -10.489494712712904,
#  'vibrant': 10.494712888195956,
#  '•': 11.593306625193023,
#  'jsl': 10.494712888195956,
#  'bentek': 10.494712888195956,
#  'walao': -10.489494712712904,
#  'wala': -10.489494712712904,
#  'sophi': -11.875768311796868,
#  'storifi': -10.489494712712904,
#  'period': -10.489494712712904,
#  'dirti': 11.187846155034885,
#  'sex': -0.22314213095608415,
#  'tum': -10.489494712712904,
#  'graphic': 11.187846155034885,
#  'background': 0.6931334116641951,
#  'moment': -0.26236361114323925,
#  'pleaaas': -10.489494712712904,
#  'mmmm': -10.489494712712904,
#  'srri': -10.489494712712904,
#  'question': 1.0986086072445307,
#  'nicola': 10.494712888195956,
#  'pa2': 10.494712888195956,
#  'venu': -10.489494712712904,
#  '642': 10.494712888195956,
#  "unicef'": -10.489494712712904,
#  'border': 10.494712888195956,
#  'disney.art': 10.494712888195956,
#  'negooo': 10.494712888195956,
#  'ride': 0.9162824559622585,
#  '89.9': 10.494712888195956,
#  'joim': 10.494712888195956,
#  "t'exist": -10.489494712712904,
#  'favourit': 0.11778266726093412,
#  'rtd': -10.489494712712904,
#  'quickest': -10.489494712712904,
#  'bierc': 10.494712888195956,
#  'crimin': -10.489494712712904,
#  'sam': -0.6931401874197693,
#  'fake': -0.6931331944252911,
#  'ideal': 11.187846155034885,
#  'realreview': 10.494712888195956,
#  '☆': 11.593306625193023,
#  'peasant': -10.489494712712904,
#  'bebe': 1.4482526596205106e-07,
#  'salut': 11.593306625193023,
#  '78x': 10.494712888195956,
#  '339': -10.489494712712904,
#  'spice': 10.494712888195956,
#  'takfaham': -10.489494712712904,
#  'honour': 10.494712888195956,
#  'the_madstork': 10.494712888195956,
#  'drinkt': 10.494712888195956,
#  'neon': 10.494712888195956,
#  'sharyl': -10.489494712712904,
#  'coveral': -10.489494712712904,
#  'swim': 1.0985938818223335,
#  'secondari': -10.489494712712904,
#  'yea': 0.6931334116641951,
#  'blame': 1.4482526596205106e-07,
#  'turkish': 10.494712888195956,
#  'mia': 1.4482526596205106e-07,
#  'sleepi': -11.588088546259256,
#  'hard-wir': -10.489494712712904,
#  'malik': 1.4482526596205106e-07,
#  'obi': 10.494712888195956,
#  'part': 0.18232110747764585,
#  'spec': 10.494712888195956,
#  'type': 0.40546054257177644,
#  'modern': 1.4482526596205106e-07,
#  'mixtap': -11.182628051963462,
#  'bilal': -10.489494712712904,
#  'koe': -10.489494712712904,
#  'ultor': 10.494712888195956,
#  'hitmark': -10.489494712712904,
#  'mne': 10.494712888195956,
#  'follow': 0.26393286648267456,
#  'haix': -11.182628051963462,
#  'hxh': 10.494712888195956,
#  'dancee': -10.489494712712904,
#  'water': -0.133530877593798,
#  'price': -0.287679717261631,
#  'sea': 1.4482526596205106e-07,
#  'x2': 10.494712888195956,
#  'could': -0.712949237543401,
#  'shorthair': 10.494712888195956,
#  '5so': -0.3364706257662502,
#  'course': 10.494712888195956,
#  'hike': -10.489494712712904,
#  'instagram': 0.5108219616664642,
#  'island': 0.6931334116641951,
#  'bit': 0.28768150477156107,
#  'silverston': 10.494712888195956,
#  'th': -11.875768311796868,
#  'creepi': -10.489494712712904,
#  'idea': 1.0560504237694128,
#  'selfish': -10.489494712712904,
#  'thursday': 0.6931334116641951,
#  'sick': -3.4657089402635233,
#  'dosa': 10.494712888195956,
#  'explain': 11.187846155034885,
#  'sethi': 11.187846155034885,
#  'wz': 10.494712888195956,
#  'wimbledon': 11.187846155034885,
#  'ass': -2.0794171744374137,
#  "blaine'": -10.489494712712904,
#  'bose': -10.489494712712904,
#  'socialmedia@dpdgroup.co.uk': 10.494712888195956,
#  'aaag': -10.489494712712904,
#  'lemess': 10.494712888195956,
#  'moodbost': -11.182628051963462,
#  '10/10': 10.494712888195956,
#  'nth': 1.4482526596205106e-07,
#  'icecream': 0.6931334116641951,
#  'agent': 10.494712888195956,
#  'mohapatra': 10.494712888195956,
#  'seungyeon': 10.494712888195956,
#  'lure': -10.489494712712904,
#  'aminn': -10.489494712712904,
#  'abouti': -10.489494712712904,
#  'yumu-youtub': -10.489494712712904,
#  'concern': -0.6931331944252911,
#  'osea': -10.489494712712904,
#  'dard': -10.489494712712904,
#  'rakyat': 10.494712888195956,
#  'madison': 10.494712888195956,
#  'b4': -10.489494712712904,
#  'garbi': 10.494712888195956,
#  'auguri': 10.494712888195956,
#  'buttt': -11.182628051963462,
#  'spade': -10.489494712712904,
#  'xoxoxo': 1.4482526596205106e-07,
#  'fabian': -11.182628051963462,
#  '2week': 1.4482526596205106e-07,
#  'overli': -10.489494712712904,
#  '💘': 0.40546054257177644,
#  'academ': -10.489494712712904,
#  'haaa': 10.494712888195956,
#  'doodl': 11.187846155034885,
#  'softbal': -10.489494712712904,
#  'mamabear': -10.489494712712904,
#  'layout': 0.6931334116641951,
#  'swisher': 10.494712888195956,
#  'groceri': -10.489494712712904,
#  'whatchya': -10.489494712712904,
#  ';p': 10.494712888195956,
#  'huge': 1.5040666472730568,
#  'dedicatedfan': 10.494712888195956,
#  'sloppi': 10.494712888195956,
#  'fyi': -10.489494712712904,
#  'bay': 1.4482526596205106e-07,
#  'sorrri': -10.489494712712904,
#  'lrka': -10.489494712712904,
#  'khami': -10.489494712712904,
#  'yeahhh': 1.4482526596205106e-07,
#  'ted': 10.494712888195956,
#  'glorifi': 10.494712888195956,
#  'pop': 0.5108219616664642,
#  'concept': -11.875768311796868,
#  'result': -0.40546042188215625,
#  'bomb': 4.8275982100776105e-08,
#  'feel': -1.3786891297836745,
#  'mvg': 10.494712888195956,
#  'open': 1.206907906947663e-08,
#  'thankyouu': -10.489494712712904,
#  'mama': 1.4482526596205106e-07,
#  'photoshoot': 10.494712888195956,
#  'everon': -10.489494712712904,
#  'light': -0.3364706257662502,
#  'akana': -10.489494712712904,
#  'ugli': -0.6931425184503057,
#  'yk': -10.489494712712904,
#  'baek': -10.489494712712904,
#  'meooowww': 10.494712888195956,
#  'total': -0.587784175218705,
#  "today'": 0.40546054257177644,
#  'kuch': 1.4482526596205106e-07,
#  'year': -0.11441025609882116,
#  'tennunb': -10.489494712712904,
#  'alienthought': 10.494712888195956,
#  'ameen': 10.494712888195956,
#  '15-24': -10.489494712712904,
#  'happyweekend': 10.494712888195956,
#  'victim': -11.588088546259256,
#  'samosa': 10.494712888195956,
#  'vlog': -10.489494712712904,
#  'ise': -10.489494712712904,
#  'emon': 10.494712888195956,
#  'avril': 10.494712888195956,
#  'must': 0.15415036061106502,
#  'stem': 10.494712888195956,
#  'linguist': -10.489494712712904,
#  'tempor': 10.494712888195956,
#  'hai': -0.133530877593798,
#  'gotcha': 10.494712888195956,
#  'lolipop': -10.489494712712904,
#  'diff': -10.489494712712904,
#  'ceo': 12.574130080736968,
#  'evet': 1.4482526596205106e-07,
#  "town'": 10.494712888195956,
#  'nia': -10.489494712712904,
#  'seen': -0.9162879394256396,
#  'purrtho': 10.494712888195956,
#  'sissi': -10.489494712712904,
#  'comedi': 10.494712888195956,
#  'np': 10.494712888195956,
#  'headach': -12.098910478960024,
#  'alvadhaau': -10.489494712712904,
#  'eek': 10.494712888195956,
#  'hungrrryyi': -10.489494712712904,
#  'manual': 7.241363808585533e-08,
#  'schade': -11.182628051963462,
#  'orchard': 10.494712888195956,
#  'playlist': 0.9162824559622585,
#  'habhab': -10.489494712712904,
#  'melodi': 10.494712888195956,
#  'attach': -10.489494712712904,
#  'iplay': 10.494712888195956,
#  'intro': 11.187846155034885,
#  'bosen': -10.489494712712904,
#  'grepe': -10.489494712712904,
#  'heel': 11.187846155034885,
#  'uncl': 10.494712888195956,
#  '15000': 10.494712888195956,
#  'laribuggi': -10.489494712712904,
#  'fluffi': -0.6931331944252911,
#  'haw': 10.494712888195956,
#  'thermal': 11.880986378661724,
#  'piggin': 10.494712888195956,
#  '7df9e60a': 10.494712888195956,
#  'pcb': -10.489494712712904,
#  'brill': 1.4482526596205106e-07,
#  'earlier': -0.9808234374403464,
#  'ngarepfollbackdarinabilahjkt': 10.494712888195956,
#  'po': 1.0985938818223335,
#  'bilbao': -10.489494712712904,
#  'x29': 10.494712888195956,
#  'nat': -10.489494712712904,
#  'three': 0.2876809370936384,
#  'unfriend': -10.489494712712904,
#  'raiz': -10.489494712712904,
#  'user': 1.0985938818223335,
#  'allgoodthingsk': 10.494712888195956,
#  'exit': -11.182628051963462,
#  '✧': -0.6931436839716449,
#  'buddi': 1.2527531024183247,
#  'dunkin': -10.489494712712904,
#  'celebr': 0.28767980174468355,
#  'patti': 10.494712888195956,
#  'problemmm': 10.494712888195956,
#  'blog': 13.790522957231639,
#  'pro': 11.880986378661724,
#  'minkyuk': -10.489494712712904,
#  'johnyherbert': 10.494712888195956,
#  '☔': -11.182628051963462,
#  'airforc': 10.494712888195956,
#  'cushion': 10.494712888195956,
#  'month': -0.4924754932347515,
#  'optim': 10.494712888195956,
#  'capee': -10.489494712712904,
#  'empow': 10.494712888195956,
#  'neglect': -10.489494712712904,
#  'gone': -1.3862891343364845,
#  'swearword': 10.494712888195956,
#  'women': -1.3862734542586985,
#  'bet': -0.2876808948519378,
#  'ee': -10.489494712712904,
#  'phl': 10.494712888195956,
#  'pose': 11.187846155034885,
#  'afterschool': -10.489494712712904,
#  'khan': 1.386273635291035,
#  '3am': -0.6931331944252911,
#  'content': 1.0985938818223335,
#  'yoona': 10.494712888195956,
#  "grigson'": -10.489494712712904,
#  'tire': -2.001475182815188,
#  'drink': 2.068981608260856e-08,
#  'hock': 10.494712888195956,
#  'tearout': 10.494712888195956,
#  'niall': -11.875768311796868,
#  'zac': 10.494712888195956,
#  'os': 1.4482526596205106e-07,
#  'llaollao': -10.489494712712904,
#  'kahaaa': -10.489494712712904,
#  'marseil': 10.494712888195956,
#  'dancer': -10.489494712712904,
#  'crew': 11.187846155034885,
#  'yesha': 10.494712888195956,
#  'nowday': -10.489494712712904,
#  'pleass': 7.241363808585533e-08,
#  'sumedh': 10.494712888195956,
#  'rrp': 10.494712888195956,
#  'laguna': -10.489494712712904,
#  'jen': 1.4482526596205106e-07,
#  'ugh': -3.1354675919099084,
#  'finger': -0.4054627649816043,
#  'center': -10.489494712712904,
#  'captur': 10.494712888195956,
#  'wut': -10.489494712712904,
#  'thurston': -10.489494712712904,
#  'notic': -0.6931454322612418,
#  'wese': 10.494712888195956,
#  'aaaand': 10.494712888195956,
#  'grown': -11.182628051963462,
#  'waytoliveahappylif': 10.494712888195956,
#  'looong': -10.489494712712904,
#  'tripathi': 10.494712888195956,
#  'holi': -10.489494712712904,
#  'hushedcallwithfraydo': 10.494712888195956,
#  'x3': 10.494712888195956,
#  'chase': 10.494712888195956,
#  'emesh': 10.494712888195956,
#  'edit': 0.4054628253267776,
#  'sabadodeganarseguidor': -0.6931331944252911,
#  'ako': 1.4482526596205106e-07,
#  'inquisitor': 10.494712888195956,
#  "s'okay": 10.494712888195956,
#  'fantast': 12.574130080736968,
#  'tune': 11.593306625193023,
#  '02079': 10.494712888195956,
#  'ikea': -10.489494712712904,
#  'yeol': -11.182628051963462,
#  'mushroom': -10.489494712712904,
#  'deliveri': 0.40546054257177644,
#  '5pm': 10.494712888195956,
#  'throw': 0.40546054257177644,
#  'biker': 10.494712888195956,
#  'musicolog': 10.494712888195956,
#  "he'll": 0.6931334116641951,
#  'bot': 1.386273635291035,
#  'bagi': -10.489494712712904,
#  'creed': -10.489494712712904,
#  'weekli': 0.6931334116641951,
#  'flawless': 10.494712888195956,
#  'elli': 11.593306625193023,
#  '인피니트': -10.489494712712904,
#  'legsupthewal': 10.494712888195956,
#  'donna': 1.0985938818223335,
#  'covent': 10.494712888195956,
#  'bakar': -10.489494712712904,
#  'babysit': -10.489494712712904,
#  'wrong': -1.098610221973293,
#  'eh': -0.40546042188215625,
#  "sister'": -10.489494712712904,
#  "dongwoo'": 10.494712888195956,
#  'chapter': -10.489494712712904,
#  'chronicl': 11.593306625193023,
#  'teen': -0.5108218844247856,
#  'bathtub': -10.489494712712904,
#  'sobrang': -10.489494712712904,
#  'imma': -11.182628051963462,
#  'oscar': 10.494712888195956,
#  'ruin': -0.6931443832863908,
#  'hahahaaah': 10.494712888195956,
#  'tan': -11.588088546259256,
#  'msged': 10.494712888195956,
#  'marvel': 0.6931334116641951,
#  'civil': 10.494712888195956,
#  'halsey': 10.494712888195956,
#  'stupid': -0.5596127856880309,
#  'pfff': -10.489494712712904,
#  'clapham': -10.489494712712904,
#  'band': 7.241363808585533e-08,
#  'gail': 10.494712888195956,
#  'donington': 10.494712888195956,
#  'naggi': 10.494712888195956,
#  'mapl': 11.187846155034885,
#  'franc': 12.104128538583506,
#  '2/3': -11.182628051963462,
#  'fugiwara': 10.494712888195956,
#  'masaantoday': 11.880986378661724,
#  'analyz': 10.494712888195956,
#  "old'": -10.489494712712904,
#  '5ever': -10.489494712712904,
#  'muna': 10.494712888195956,
#  'wolrd': -10.489494712712904,
#  'jenni': 10.494712888195956,
#  '14518344': -10.489494712712904,
#  'u': -0.10462492979346916,
#  'headphon': -10.489494712712904,
#  'daaru': 10.494712888195956,
#  'barcelona': -10.489494712712904,
#  'hillari': 10.494712888195956,
#  'brambhatt': 10.494712888195956,
#  'usah': 10.494712888195956,
#  'arch': -10.489494712712904,
#  'christoph': 11.187846155034885,
#  'gon': -10.489494712712904,
#  '6': 0.530627119687828,
#  'rate': -1.0985936887210854,
#  'arriv': 2.656750474151032,
#  'sebastian': -10.489494712712904,
#  '🍹': -11.588088546259256,
#  'appendix': -10.489494712712904,
#  'polic': -11.182628051963462,
#  'cover': 1.2527531024183247,
#  '💜': 2.4138102849846632e-08,
#  'sch': -10.489494712712904,
#  'traffick': 1.4482526596205106e-07,
#  'ebook': -10.489494712712904,
#  'burdensom': -10.489494712712904,
#  'ito': 11.187846155034885,
#  'visit': 0.9162890766789267,
#  'flaw': 10.494712888195956,
#  'extra': 0.9162824559622585,
#  'trip': 0.08701117933805147,
#  'hard': -1.2039706351008728,
#  'motilium': -10.489494712712904,
#  'youu': -11.182628051963462,
#  'needa': 10.494712888195956,
#  'dire': -11.182628051963462,
#  'jr': 10.494712888195956,
#  'cherri': -10.489494712712904,
#  'hq': 10.494712888195956,
#  'manni': 10.494712888195956,
#  'chang': -0.1397617545913712,
#  'ty': 0.28767980174468355,
#  'yummm': 10.494712888195956,
#  'x42': 10.494712888195956,
#  'deliri': -10.489494712712904,
#  'hahahaokay': -10.489494712712904,
#  'decent': 7.241363808585533e-08,
#  'safer': -10.489494712712904,
#  'dreamili': 10.494712888195956,
#  'arc': 10.494712888195956,
#  'irish': 11.187846155034885,
#  'ho': -0.6931331944252911,
#  'breach': 10.494712888195956,
#  'likeforfollow': -11.588088546259256,
#  'sleeep': -11.588088546259256,
#  'bh3': -10.489494712712904,
#  'bbb': 10.494712888195956,
#  'shanzay': -10.489494712712904,
#  'shirleycam': -10.489494712712904,
#  'madi': -11.182628051963462,
#  'festiv': 1.2527531024183247,
#  'theo': -10.489494712712904,
#  'hornykik': -1.9458982125097142,
#  'sandrabland': -12.098910478960024,
#  'whoop': 11.880986378661724,
#  'gay': -0.6931425184503057,
#  'code': -0.6931425184503057,
#  'afteral': 10.494712888195956,
#  'rito': -10.489494712712904,
#  'sudden': -11.875768311796868,
#  'sugarrush': 10.494712888195956,
#  'limbo': 10.494712888195956,
#  'wale': 11.187846155034885,
#  'unam': 10.494712888195956,
#  'coco': 11.187846155034885,
#  'happili': 1.4482526596205106e-07,
#  'pech': 10.494712888195956,
#  'naaan': -10.489494712712904,
#  'blamehoney': -10.489494712712904,
#  'vishwa': -10.489494712712904,
#  '╱': 12.104128538583506,
#  'beli̇ev': -14.044815882340032,
#  'trish': 10.494712888195956,
#  'waah': -10.489494712712904,
#  'research': 1.4482526596205106e-07,
#  'vyapam': 11.187846155034885,
#  'chuckl': 10.494712888195956,
#  "monty'": 10.494712888195956,
#  'flavour': -10.489494712712904,
#  'rout': 11.187846155034885,
#  'engag': 12.440599185039572,
#  'bcu': 10.494712888195956,
#  'ms': -10.489494712712904,
#  'acid': 10.494712888195956,
#  'scar': 10.494712888195956,
#  '😍': 10.494712888195956,
#  '500': 0.6931334116641951,
#  'sampl': -10.489494712712904,
#  'entlerbountli': -10.489494712712904,
#  'opinion': 11.187846155034885,
#  'amargolonnard': -10.489494712712904,
#  'earl': 10.494712888195956,
#  'emta': -10.489494712712904,
#  'star': 0.9808235038199262,
#  'desper': -11.182628051963462,
#  'australia': 0.6931402960404779,
#  'countthecost': -10.489494712712904,
#  'whilst': -1.0985936887210854,
#  'olymp': -10.489494712712904,
#  'goa': -10.489494712712904,
#  'tunaita': -10.489494712712904,
#  'alic': 11.880986378661724,
#  'riski': -10.489494712712904,
#  'smtm': -10.489494712712904,
#  'piano': -11.182628051963462,
#  'com': 0.6931334116641951,
#  "shamuon'": -10.489494712712904,
#  'foundat': -10.489494712712904,
#  'testicl': 10.494712888195956,
#  'dam': 10.494712888195956,
#  'proper': -0.6931331944252911,
#  'aswel': 10.494712888195956,
#  'arma': 10.494712888195956,
#  'blockjam': -10.489494712712904,
#  'tram': -10.489494712712904,
#  'power': 0.18232065816362297,
#  'legend': -11.182628051963462,
#  '7df89150': -10.489494712712904,
#  'heheh': 10.494712888195956,
#  '30juli': 10.494712888195956,
#  'minal': 10.494712888195956,
#  'specif': -11.182628051963462,
#  'rehash': -10.489494712712904,
#  'girli': 10.494712888195956,
#  'merci': 1.4482526596205106e-07,
#  'segalakatakata': 10.494712888195956,
#  'ledger': -10.489494712712904,
#  'dinner': 0.4054628253267776,
#  'ubericecream': -13.05441851683824,
#  'word': 0.26826349406170014,
#  'brighton': 10.494712888195956,
#  'thirdwheel': -10.489494712712904,
#  'omgg': 10.494712888195956,
#  'immun': -10.489494712712904,
#  'kath': 11.593306625193023,
#  'wow': 1.2527580354348737,
#  'mam-bulli': -10.489494712712904,
#  'tulan': 10.494712888195956,
#  'feder': 10.494712888195956,
#  'camp': -12.43538113369197,
#  'clip': 1.4482526596205106e-07,
#  'congraaat': 10.494712888195956,
#  'yeheyi': 10.494712888195956,
#  'saar': 10.494712888195956,
#  '15ml': 10.494712888195956,
#  'walang': -10.489494712712904,
#  'thapelo': -10.489494712712904,
#  '🌃': -10.489494712712904,
#  'noob': -10.489494712712904,
#  'vianey': 10.494712888195956,
#  'aaahhh': 1.4482526596205106e-07,
#  'abl': -1.0414508652569365,
#  'proudtobem': 10.494712888195956,
#  'sunday': -0.15414999656832373,
#  'sri': -10.489494712712904,
#  'nvm': -11.182628051963462,
#  'tammirossm': -11.875768311796868,
#  'growl': -10.489494712712904,
#  'spot': -0.40546042188215625,
#  'ark': 10.494712888195956,
#  'note': 1.386273635291035,
#  'pricelessantiqu': 10.494712888195956,
#  'tc': 10.494712888195956,
#  'naya': -10.489494712712904,
#  'nim': 10.494712888195956,
#  '18c': -10.489494712712904,
#  '」': -11.182628051963462,
#  'mostli': 10.494712888195956,
#  'ador': 0.6931334116641951,
#  'happyyi': 10.494712888195956,
#  '1100d': 10.494712888195956,
#  '2:30': -11.182628051963462,
#  "cathy'": -10.489494712712904,
#  'dd': 1.4482526596205106e-07,
#  'heart': -1.2992796044634,
#  'peachyloan': 10.494712888195956,
#  'gangster': 10.494712888195956,
#  'everi': 0.7375976363932919,
#  'ed': -12.098910478960024,
#  '12pm': 10.494712888195956,
#  'gimm': -11.182628051963462,
#  'opt': -10.489494712712904,
#  'shade': -1.0985936887210854,
#  'broke': -1.7917362554473732,
#  'aich': 10.494712888195956,
#  'j': 0.6931334116641951,
#  'aaaaaaaaah': -10.489494712712904,
#  'swag': 1.4482526596205106e-07,
#  'knit': 10.494712888195956,
#  'na-tak': -10.489494712712904,
#  'imintoh': -10.489494712712904,
#  'siregar': 10.494712888195956,
#  ...}

# %%
def sentiment_predictor(tweet, logprior, loglikelihood):
    words_in_tweet = clean_tweet(tweet)
    
    p=logprior
    
    for word in words_in_tweet:
        if word in loglikelihood:
            p += loglikelihood[word]
#     if p>1:
#         sentiment='positive'
#     else:
#         sentiment='negative'
    return p

# %%
my_tweet = 'this is bad'
p = sentiment_predictor(my_tweet, logprior, loglikelihood)
print('The expected output is', p)
# Out:
# The expected output is -1.3499252418866763

# %%
def test_naive_bayes(test_x, test_y, logprior, loglikelihood):
    """
    Input:
        test_x: A list of tweets
        test_y: the corresponding labels for the list of tweets
        logprior: the logprior
        loglikelihood: a dictionary with the loglikelihoods for each word
    Output:
        accuracy: (# of tweets classified correctly)/(total # of tweets)
    """
    accuracy = 0  # return this properly

    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    y_hats = []
    for tweet in test_x:
        # if the prediction is > 0
        if sentiment_predictor(tweet, logprior, loglikelihood) > 0:
            # the predicted class is 1
            y_hat_i = 1
        else:
            # otherwise the predicted class is 0
            y_hat_i = 0

        # append the predicted class to the list y_hats
        y_hats.append(y_hat_i)

    # error is the average of the absolute values of the differences between y_hats and test_y
    error = np.mean(np.absolute(y_hats-test_y))

    # Accuracy is 1 minus the error
    accuracy = 1-error

    ### END CODE HERE ###

    return accuracy

# %%
print("Naive Bayes accuracy = %0.4f" %
      (test_naive_bayes(test_x, test_y, logprior, loglikelihood)))
# Out:
# Naive Bayes accuracy = 0.9095
